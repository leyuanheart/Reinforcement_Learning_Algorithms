# %%
import os
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
seed = 123
os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
np.random.seed(seed)
env.seed(seed)

# %% [markdown]
# # FrozenLake-v0
#
# [介绍](https://gym.openai.com/envs/FrozenLake-v0/)

# %% [markdown]
# ## Q-learning

# %%
name = "FrozenLake-v0"
env = gym.make(name)


off_policy = True # if True use q-learning, if False use Sarsa


t_max = 10000
def run_episode(env, policy=None, render=False):
    obs = env.reset()
    total_reward = 0
    steps = 0
    for _ in range(t_max):
        if render:
            env.render()
        '''
        we could also only print the last state (to see if our agent is on the goal or fall into an hole)
        put the 'env.render()' into the 'done:'
        '''
        if policy is None:
            action = env.action_space.sample()
        else:
            action = policy[obs]
        obs, reward, done, _ = env.step(action)
        total_reward += gamma**steps * reward
        steps += 1
        
        if done:
            break
    return total_reward


iter_max = int(1e6)
initial_lr = 1.0
min_lr = 0.003
gamma = 1.0
eps = 0.1
env.seed(123)
np.random.seed(123)

if off_policy == True:
    print ('----- using Q Learning -----')
else:
    print('------ using SARSA Learning ---')

q_table = np.zeros((env.observation_space.n, env.action_space.n))   # (16, 4)

returns = []
for i in range(iter_max):
    obs = env.reset()
    total_reward = 0
    # eta: learning rate is decayed every 100 steps
    eta = max(min_lr, initial_lr * (0.85**(i//100)))
    
    for j in range(t_max):
        if np.random.uniform(0, 1) < eps:
            action = np.random.choice(env.action_space.n)
        else:
            action = np.argmax(q_table[obs])
        
        obs_tp1, reward, done, _ = env.step(action)
        total_reward += reward
        
        # update q table
        if off_policy == True:
            # q-learning
            target = reward + gamma * np.max(q_table[obs_tp1]) * (1 - done)
            q_table[obs][action] = q_table[obs][action] + eta * (target - q_table[obs][action])
        else:
            # Sarsa
            if np.random.uniform(0, 1) < eps:
                action_ = np.random.choice(env.action_space.n)
            else:
                action_ = np.argmax(q_table[obs_tp1])
            target = reward + gamma * q_table[obs_tp1][action_] * (1 - done)
            q_table[obs][action] = q_table[obs][action] + eta * (target - q_table[obs][action])
        
        obs = obs_tp1
        
        if done:
            returns.append(total_reward)
            break
        
    if i % 200 == 0:
        print('Iteration #%d -- Total reward = %d.' %(i+1, total_reward))
        
    if np.array(returns[-100:]).mean() > 0.7:
        break
        
    
solution_policy = np.argmax(q_table, axis=1)
solution_policy_scores = [run_episode(env, solution_policy, False) for _ in range(100)]
print("Average score of solution = ", np.mean(solution_policy_scores))

# Animate it
if np.mean(solution_policy_scores) > 0.7: 
    for i in range(2):
        print('episode {}'.format(i))
        run_episode(env, solution_policy, True)
env.close()
# Out:
# ----- using Q Learning -----
# Iteration #1 -- Total reward = 0.
# Iteration #201 -- Total reward = 0.
# Iteration #401 -- Total reward = 0.
# Iteration #601 -- Total reward = 0.
# Iteration #801 -- Total reward = 0.
# Iteration #1001 -- Total reward = 0.
# Iteration #1201 -- Total reward = 0.
# Iteration #1401 -- Total reward = 0.
# Iteration #1601 -- Total reward = 0.
# Iteration #1801 -- Total reward = 0.
# Iteration #2001 -- Total reward = 0.
# Iteration #2201 -- Total reward = 0.
# Iteration #2401 -- Total reward = 0.
# Iteration #2601 -- Total reward = 0.
# Iteration #2801 -- Total reward = 0.
# Iteration #3001 -- Total reward = 0.
# Iteration #3201 -- Total reward = 0.
# Iteration #3401 -- Total reward = 0.
# Iteration #3601 -- Total reward = 0.
# Iteration #3801 -- Total reward = 0.
# Iteration #4001 -- Total reward = 0.
# Iteration #4201 -- Total reward = 0.
# Iteration #4401 -- Total reward = 0.
# Iteration #4601 -- Total reward = 0.
# Iteration #4801 -- Total reward = 0.
# Iteration #5001 -- Total reward = 0.
# Iteration #5201 -- Total reward = 0.
# Iteration #5401 -- Total reward = 0.
# Iteration #5601 -- Total reward = 0.
# Iteration #5801 -- Total reward = 0.
# Iteration #6001 -- Total reward = 0.
# Iteration #6201 -- Total reward = 0.
# Iteration #6401 -- Total reward = 0.
# Iteration #6601 -- Total reward = 0.
# Iteration #6801 -- Total reward = 0.
# Iteration #7001 -- Total reward = 0.
# Iteration #7201 -- Total reward = 0.
# Iteration #7401 -- Total reward = 0.
# Iteration #7601 -- Total reward = 0.
# Iteration #7801 -- Total reward = 0.
# Iteration #8001 -- Total reward = 0.
# Iteration #8201 -- Total reward = 0.
# Iteration #8401 -- Total reward = 0.
# Iteration #8601 -- Total reward = 0.
# Iteration #8801 -- Total reward = 0.
# Iteration #9001 -- Total reward = 0.
# Iteration #9201 -- Total reward = 0.
# Iteration #9401 -- Total reward = 0.
# Iteration #9601 -- Total reward = 0.
# Iteration #9801 -- Total reward = 0.
# Iteration #10001 -- Total reward = 0.
# Iteration #10201 -- Total reward = 0.
# Iteration #10401 -- Total reward = 0.
# Iteration #10601 -- Total reward = 0.
# Iteration #10801 -- Total reward = 0.
# Iteration #11001 -- Total reward = 0.
# Iteration #11201 -- Total reward = 0.
# Iteration #11401 -- Total reward = 0.
# Iteration #11601 -- Total reward = 0.
# Iteration #11801 -- Total reward = 0.
# Iteration #12001 -- Total reward = 0.
# Iteration #12201 -- Total reward = 0.
# Iteration #12401 -- Total reward = 0.
# Iteration #12601 -- Total reward = 0.
# Iteration #12801 -- Total reward = 0.
# Iteration #13001 -- Total reward = 0.
# Iteration #13201 -- Total reward = 0.
# Iteration #13401 -- Total reward = 0.
# Iteration #13601 -- Total reward = 0.
# Iteration #13801 -- Total reward = 0.
# Iteration #14001 -- Total reward = 0.
# Iteration #14201 -- Total reward = 0.
# Iteration #14401 -- Total reward = 0.
# Iteration #14601 -- Total reward = 0.
# Iteration #14801 -- Total reward = 0.
# Iteration #15001 -- Total reward = 0.
# Iteration #15201 -- Total reward = 0.
# Iteration #15401 -- Total reward = 0.
# Iteration #15601 -- Total reward = 0.
# Iteration #15801 -- Total reward = 0.
# Iteration #16001 -- Total reward = 0.
# Iteration #16201 -- Total reward = 0.
# Iteration #16401 -- Total reward = 0.
# Iteration #16601 -- Total reward = 0.
# Iteration #16801 -- Total reward = 0.
# Iteration #17001 -- Total reward = 0.
# Iteration #17201 -- Total reward = 0.
# Iteration #17401 -- Total reward = 0.
# Iteration #17601 -- Total reward = 0.
# Iteration #17801 -- Total reward = 0.
# Iteration #18001 -- Total reward = 0.
# Iteration #18201 -- Total reward = 0.
# Iteration #18401 -- Total reward = 0.
# Iteration #18601 -- Total reward = 0.
# Iteration #18801 -- Total reward = 0.
# Iteration #19001 -- Total reward = 0.
# Iteration #19201 -- Total reward = 0.
# Iteration #19401 -- Total reward = 0.
# Iteration #19601 -- Total reward = 0.
# Iteration #19801 -- Total reward = 0.
# Iteration #20001 -- Total reward = 0.
# Iteration #20201 -- Total reward = 0.
# Iteration #20401 -- Total reward = 0.
# Iteration #20601 -- Total reward = 0.
# Iteration #20801 -- Total reward = 0.
# Iteration #21001 -- Total reward = 0.
# Iteration #21201 -- Total reward = 0.
# Iteration #21401 -- Total reward = 0.
# Iteration #21601 -- Total reward = 0.
# Iteration #21801 -- Total reward = 0.
# Iteration #22001 -- Total reward = 0.
# Iteration #22201 -- Total reward = 0.
# Iteration #22401 -- Total reward = 0.
# Iteration #22601 -- Total reward = 0.
# Iteration #22801 -- Total reward = 0.
# Iteration #23001 -- Total reward = 0.
# Iteration #23201 -- Total reward = 0.
# Iteration #23401 -- Total reward = 0.
# Iteration #23601 -- Total reward = 0.
# Iteration #23801 -- Total reward = 0.
# Iteration #24001 -- Total reward = 0.
# Iteration #24201 -- Total reward = 0.
# Iteration #24401 -- Total reward = 0.
# Iteration #24601 -- Total reward = 0.
# Iteration #24801 -- Total reward = 0.
# Iteration #25001 -- Total reward = 0.
# Iteration #25201 -- Total reward = 0.
# Iteration #25401 -- Total reward = 0.
# Iteration #25601 -- Total reward = 0.
# Iteration #25801 -- Total reward = 0.
# Iteration #26001 -- Total reward = 0.
# Iteration #26201 -- Total reward = 0.
# Iteration #26401 -- Total reward = 0.
# Iteration #26601 -- Total reward = 0.
# Iteration #26801 -- Total reward = 0.
# Iteration #27001 -- Total reward = 0.
# Iteration #27201 -- Total reward = 0.
# Iteration #27401 -- Total reward = 0.
# Iteration #27601 -- Total reward = 0.
# Iteration #27801 -- Total reward = 0.
# Iteration #28001 -- Total reward = 0.
# Iteration #28201 -- Total reward = 0.
# Iteration #28401 -- Total reward = 0.
# Iteration #28601 -- Total reward = 0.
# Iteration #28801 -- Total reward = 0.
# Iteration #29001 -- Total reward = 0.
# Iteration #29201 -- Total reward = 0.
# Iteration #29401 -- Total reward = 0.
# Iteration #29601 -- Total reward = 0.
# Iteration #29801 -- Total reward = 0.
# Iteration #30001 -- Total reward = 0.
# Iteration #30201 -- Total reward = 0.
# Iteration #30401 -- Total reward = 0.
# Iteration #30601 -- Total reward = 0.
# Iteration #30801 -- Total reward = 0.
# Iteration #31001 -- Total reward = 0.
# Iteration #31201 -- Total reward = 0.
# Iteration #31401 -- Total reward = 0.
# Iteration #31601 -- Total reward = 0.
# Iteration #31801 -- Total reward = 0.
# Iteration #32001 -- Total reward = 0.
# Iteration #32201 -- Total reward = 0.
# Iteration #32401 -- Total reward = 0.
# Iteration #32601 -- Total reward = 0.
# Iteration #32801 -- Total reward = 0.
# Iteration #33001 -- Total reward = 0.
# Iteration #33201 -- Total reward = 0.
# Iteration #33401 -- Total reward = 0.
# Iteration #33601 -- Total reward = 0.
# Iteration #33801 -- Total reward = 0.
# Iteration #34001 -- Total reward = 0.
# Iteration #34201 -- Total reward = 0.
# Iteration #34401 -- Total reward = 0.
# Iteration #34601 -- Total reward = 0.
# Iteration #34801 -- Total reward = 0.
# Iteration #35001 -- Total reward = 0.
# Iteration #35201 -- Total reward = 0.
# Iteration #35401 -- Total reward = 0.
# Iteration #35601 -- Total reward = 0.
# Iteration #35801 -- Total reward = 0.
# Iteration #36001 -- Total reward = 0.
# Iteration #36201 -- Total reward = 0.
# Iteration #36401 -- Total reward = 0.
# Iteration #36601 -- Total reward = 0.
# Iteration #36801 -- Total reward = 0.
# Iteration #37001 -- Total reward = 0.
# Iteration #37201 -- Total reward = 0.
# Iteration #37401 -- Total reward = 0.
# Iteration #37601 -- Total reward = 0.
# Iteration #37801 -- Total reward = 0.
# Iteration #38001 -- Total reward = 0.
# Iteration #38201 -- Total reward = 0.
# Iteration #38401 -- Total reward = 0.
# Iteration #38601 -- Total reward = 0.
# Iteration #38801 -- Total reward = 0.
# Iteration #39001 -- Total reward = 0.
# Iteration #39201 -- Total reward = 0.
# Iteration #39401 -- Total reward = 0.
# Iteration #39601 -- Total reward = 0.
# Iteration #39801 -- Total reward = 0.
# Iteration #40001 -- Total reward = 0.
# Iteration #40201 -- Total reward = 0.
# Iteration #40401 -- Total reward = 0.
# Iteration #40601 -- Total reward = 0.
# Iteration #40801 -- Total reward = 0.
# Iteration #41001 -- Total reward = 0.
# Iteration #41201 -- Total reward = 0.
# Iteration #41401 -- Total reward = 0.
# Iteration #41601 -- Total reward = 0.
# Iteration #41801 -- Total reward = 0.
# Iteration #42001 -- Total reward = 0.
# Iteration #42201 -- Total reward = 0.
# Iteration #42401 -- Total reward = 0.
# Iteration #42601 -- Total reward = 0.
# Iteration #42801 -- Total reward = 0.
# Iteration #43001 -- Total reward = 0.
# Iteration #43201 -- Total reward = 0.
# Iteration #43401 -- Total reward = 0.
# Iteration #43601 -- Total reward = 0.
# Iteration #43801 -- Total reward = 0.
# Iteration #44001 -- Total reward = 0.
# Iteration #44201 -- Total reward = 0.
# Iteration #44401 -- Total reward = 0.
# Iteration #44601 -- Total reward = 0.
# Iteration #44801 -- Total reward = 0.
# Iteration #45001 -- Total reward = 0.
# Iteration #45201 -- Total reward = 0.
# Iteration #45401 -- Total reward = 0.
# Iteration #45601 -- Total reward = 0.
# Iteration #45801 -- Total reward = 0.
# Iteration #46001 -- Total reward = 0.
# Iteration #46201 -- Total reward = 0.
# Iteration #46401 -- Total reward = 0.
# Iteration #46601 -- Total reward = 0.
# Iteration #46801 -- Total reward = 0.
# Iteration #47001 -- Total reward = 0.
# Iteration #47201 -- Total reward = 0.
# Iteration #47401 -- Total reward = 0.
# Iteration #47601 -- Total reward = 0.
# Iteration #47801 -- Total reward = 0.
# Iteration #48001 -- Total reward = 0.
# Iteration #48201 -- Total reward = 0.
# Iteration #48401 -- Total reward = 0.
# Iteration #48601 -- Total reward = 0.
# Iteration #48801 -- Total reward = 0.
# Iteration #49001 -- Total reward = 0.
# Iteration #49201 -- Total reward = 1.
# Iteration #49401 -- Total reward = 1.
# Iteration #49601 -- Total reward = 0.
# Iteration #49801 -- Total reward = 0.
# Iteration #50001 -- Total reward = 0.
# Iteration #50201 -- Total reward = 0.
# Iteration #50401 -- Total reward = 0.
# Iteration #50601 -- Total reward = 0.
# Iteration #50801 -- Total reward = 0.
# Iteration #51001 -- Total reward = 0.
# Iteration #51201 -- Total reward = 0.
# Iteration #51401 -- Total reward = 0.
# Iteration #51601 -- Total reward = 0.
# Iteration #51801 -- Total reward = 1.
# Iteration #52001 -- Total reward = 0.
# Iteration #52201 -- Total reward = 0.
# Iteration #52401 -- Total reward = 0.
# Iteration #52601 -- Total reward = 0.
# Iteration #52801 -- Total reward = 0.
# Iteration #53001 -- Total reward = 0.
# Iteration #53201 -- Total reward = 1.
# Iteration #53401 -- Total reward = 0.
# Iteration #53601 -- Total reward = 0.
# Iteration #53801 -- Total reward = 1.
# Iteration #54001 -- Total reward = 1.
# Iteration #54201 -- Total reward = 0.
# Iteration #54401 -- Total reward = 0.
# Iteration #54601 -- Total reward = 0.
# Iteration #54801 -- Total reward = 0.
# Iteration #55001 -- Total reward = 0.
# Iteration #55201 -- Total reward = 0.
# Iteration #55401 -- Total reward = 0.
# Iteration #55601 -- Total reward = 0.
# Iteration #55801 -- Total reward = 0.
# Iteration #56001 -- Total reward = 0.
# Iteration #56201 -- Total reward = 0.
# Iteration #56401 -- Total reward = 0.
# Iteration #56601 -- Total reward = 0.
# Iteration #56801 -- Total reward = 0.
# Iteration #57001 -- Total reward = 0.
# Iteration #57201 -- Total reward = 0.
# Iteration #57401 -- Total reward = 0.
# Iteration #57601 -- Total reward = 0.
# Iteration #57801 -- Total reward = 0.
# Iteration #58001 -- Total reward = 0.
# Iteration #58201 -- Total reward = 0.
# Iteration #58401 -- Total reward = 0.
# Iteration #58601 -- Total reward = 0.
# Iteration #58801 -- Total reward = 0.
# Iteration #59001 -- Total reward = 0.
# Iteration #59201 -- Total reward = 1.
# Iteration #59401 -- Total reward = 0.
# Iteration #59601 -- Total reward = 1.
# Iteration #59801 -- Total reward = 0.
# Iteration #60001 -- Total reward = 1.
# Iteration #60201 -- Total reward = 0.
# Iteration #60401 -- Total reward = 0.
# Iteration #60601 -- Total reward = 0.
# Iteration #60801 -- Total reward = 0.
# Iteration #61001 -- Total reward = 0.
# Iteration #61201 -- Total reward = 0.
# Iteration #61401 -- Total reward = 0.
# Iteration #61601 -- Total reward = 0.
# Iteration #61801 -- Total reward = 0.
# Iteration #62001 -- Total reward = 0.
# Iteration #62201 -- Total reward = 0.
# Iteration #62401 -- Total reward = 0.
# Iteration #62601 -- Total reward = 0.
# Iteration #62801 -- Total reward = 0.
# Iteration #63001 -- Total reward = 0.
# Iteration #63201 -- Total reward = 0.
# Iteration #63401 -- Total reward = 0.
# Iteration #63601 -- Total reward = 0.
# Iteration #63801 -- Total reward = 0.
# Iteration #64001 -- Total reward = 0.
# Iteration #64201 -- Total reward = 0.
# Iteration #64401 -- Total reward = 0.
# Iteration #64601 -- Total reward = 0.
# Iteration #64801 -- Total reward = 0.
# Iteration #65001 -- Total reward = 1.
# Iteration #65201 -- Total reward = 0.
# Iteration #65401 -- Total reward = 1.
# Iteration #65601 -- Total reward = 0.
# Iteration #65801 -- Total reward = 0.
# Iteration #66001 -- Total reward = 0.
# Iteration #66201 -- Total reward = 0.
# Iteration #66401 -- Total reward = 0.
# Iteration #66601 -- Total reward = 1.
# Iteration #66801 -- Total reward = 0.
# Iteration #67001 -- Total reward = 0.
# Iteration #67201 -- Total reward = 0.
# Iteration #67401 -- Total reward = 0.
# Iteration #67601 -- Total reward = 0.
# Iteration #67801 -- Total reward = 0.
# Iteration #68001 -- Total reward = 1.
# Iteration #68201 -- Total reward = 0.
# Iteration #68401 -- Total reward = 0.
# Iteration #68601 -- Total reward = 0.
# Iteration #68801 -- Total reward = 0.
# Iteration #69001 -- Total reward = 0.
# Iteration #69201 -- Total reward = 0.
# Iteration #69401 -- Total reward = 0.
# Iteration #69601 -- Total reward = 1.
# Iteration #69801 -- Total reward = 0.
# Iteration #70001 -- Total reward = 0.
# Iteration #70201 -- Total reward = 0.
# Iteration #70401 -- Total reward = 0.
# Iteration #70601 -- Total reward = 0.
# Iteration #70801 -- Total reward = 0.
# Iteration #71001 -- Total reward = 0.
# Iteration #71201 -- Total reward = 0.
# Iteration #71401 -- Total reward = 1.
# Iteration #71601 -- Total reward = 0.
# Iteration #71801 -- Total reward = 0.
# Iteration #72001 -- Total reward = 0.
# Iteration #72201 -- Total reward = 1.
# Iteration #72401 -- Total reward = 0.
# Iteration #72601 -- Total reward = 0.
# Iteration #72801 -- Total reward = 0.
# Iteration #73001 -- Total reward = 0.
# Iteration #73201 -- Total reward = 0.
# Iteration #73401 -- Total reward = 0.
# Iteration #73601 -- Total reward = 0.
# Iteration #73801 -- Total reward = 0.
# Iteration #74001 -- Total reward = 0.
# Iteration #74201 -- Total reward = 0.
# Iteration #74401 -- Total reward = 0.
# Iteration #74601 -- Total reward = 0.
# Iteration #74801 -- Total reward = 0.
# Iteration #75001 -- Total reward = 1.
# Iteration #75201 -- Total reward = 0.
# Iteration #75401 -- Total reward = 0.
# Iteration #75601 -- Total reward = 0.
# Iteration #75801 -- Total reward = 0.
# Iteration #76001 -- Total reward = 0.
# Iteration #76201 -- Total reward = 0.
# Iteration #76401 -- Total reward = 0.
# Iteration #76601 -- Total reward = 0.
# Iteration #76801 -- Total reward = 0.
# Iteration #77001 -- Total reward = 0.
# Iteration #77201 -- Total reward = 0.
# Iteration #77401 -- Total reward = 0.
# Iteration #77601 -- Total reward = 0.
# Iteration #77801 -- Total reward = 0.
# Iteration #78001 -- Total reward = 0.
# Iteration #78201 -- Total reward = 1.
# Iteration #78401 -- Total reward = 0.
# Iteration #78601 -- Total reward = 1.
# Iteration #78801 -- Total reward = 0.
# Iteration #79001 -- Total reward = 0.
# Iteration #79201 -- Total reward = 0.
# Iteration #79401 -- Total reward = 0.
# Iteration #79601 -- Total reward = 0.
# Iteration #79801 -- Total reward = 0.
# Iteration #80001 -- Total reward = 0.
# Iteration #80201 -- Total reward = 1.
# Iteration #80401 -- Total reward = 0.
# Iteration #80601 -- Total reward = 1.
# Iteration #80801 -- Total reward = 0.
# Iteration #81001 -- Total reward = 1.
# Iteration #81201 -- Total reward = 0.
# Iteration #81401 -- Total reward = 1.
# Iteration #81601 -- Total reward = 1.
# Iteration #81801 -- Total reward = 0.
# Iteration #82001 -- Total reward = 0.
# Iteration #82201 -- Total reward = 0.
# Iteration #82401 -- Total reward = 0.
# Iteration #82601 -- Total reward = 0.
# Iteration #82801 -- Total reward = 0.
# Iteration #83001 -- Total reward = 0.
# Iteration #83201 -- Total reward = 0.
# Iteration #83401 -- Total reward = 0.
# Iteration #83601 -- Total reward = 1.
# Iteration #83801 -- Total reward = 0.
# Iteration #84001 -- Total reward = 0.
# Iteration #84201 -- Total reward = 0.
# Iteration #84401 -- Total reward = 1.
# Iteration #84601 -- Total reward = 0.
# Iteration #84801 -- Total reward = 0.
# Iteration #85001 -- Total reward = 0.
# Iteration #85201 -- Total reward = 0.
# Iteration #85401 -- Total reward = 0.
# Iteration #85601 -- Total reward = 0.
# Iteration #85801 -- Total reward = 0.
# Iteration #86001 -- Total reward = 0.
# Iteration #86201 -- Total reward = 0.
# Iteration #86401 -- Total reward = 0.
# Iteration #86601 -- Total reward = 0.
# Iteration #86801 -- Total reward = 0.
# Iteration #87001 -- Total reward = 1.
# Iteration #87201 -- Total reward = 1.
# Iteration #87401 -- Total reward = 0.
# Iteration #87601 -- Total reward = 0.
# Iteration #87801 -- Total reward = 0.
# Iteration #88001 -- Total reward = 0.
# Iteration #88201 -- Total reward = 1.
# Iteration #88401 -- Total reward = 0.
# Iteration #88601 -- Total reward = 1.
# Iteration #88801 -- Total reward = 1.
# Iteration #89001 -- Total reward = 0.
# Iteration #89201 -- Total reward = 0.
# Iteration #89401 -- Total reward = 0.
# Iteration #89601 -- Total reward = 0.
# Iteration #89801 -- Total reward = 0.
# Iteration #90001 -- Total reward = 0.
# Iteration #90201 -- Total reward = 0.
# Iteration #90401 -- Total reward = 0.
# Iteration #90601 -- Total reward = 0.
# Iteration #90801 -- Total reward = 0.
# Iteration #91001 -- Total reward = 0.
# Iteration #91201 -- Total reward = 0.
# Iteration #91401 -- Total reward = 1.
# Iteration #91601 -- Total reward = 0.
# Iteration #91801 -- Total reward = 0.
# Iteration #92001 -- Total reward = 0.
# Iteration #92201 -- Total reward = 0.
# Iteration #92401 -- Total reward = 0.
# Iteration #92601 -- Total reward = 0.
# Iteration #92801 -- Total reward = 0.
# Iteration #93001 -- Total reward = 0.
# Iteration #93201 -- Total reward = 1.
# Iteration #93401 -- Total reward = 0.
# Iteration #93601 -- Total reward = 0.
# Iteration #93801 -- Total reward = 1.
# Iteration #94001 -- Total reward = 0.
# Iteration #94201 -- Total reward = 0.
# Iteration #94401 -- Total reward = 0.
# Iteration #94601 -- Total reward = 0.
# Iteration #94801 -- Total reward = 0.
# Iteration #95001 -- Total reward = 0.
# Iteration #95201 -- Total reward = 1.
# Iteration #95401 -- Total reward = 1.
# Iteration #95601 -- Total reward = 0.
# Iteration #95801 -- Total reward = 0.
# Iteration #96001 -- Total reward = 1.
# Iteration #96201 -- Total reward = 0.
# Iteration #96401 -- Total reward = 1.
# Iteration #96601 -- Total reward = 1.
# Iteration #96801 -- Total reward = 0.
# Iteration #97001 -- Total reward = 0.
# Iteration #97201 -- Total reward = 0.
# Iteration #97401 -- Total reward = 0.
# Iteration #97601 -- Total reward = 0.
# Iteration #97801 -- Total reward = 1.
# Iteration #98001 -- Total reward = 0.
# Iteration #98201 -- Total reward = 0.
# Iteration #98401 -- Total reward = 0.
# Iteration #98601 -- Total reward = 0.
# Iteration #98801 -- Total reward = 0.
# Iteration #99001 -- Total reward = 1.
# Iteration #99201 -- Total reward = 1.
# Iteration #99401 -- Total reward = 1.
# Iteration #99601 -- Total reward = 1.
# Iteration #99801 -- Total reward = 0.
# Iteration #100001 -- Total reward = 0.
# Iteration #100201 -- Total reward = 1.
# Iteration #100401 -- Total reward = 0.
# Iteration #100601 -- Total reward = 0.
# Iteration #100801 -- Total reward = 0.
# Iteration #101001 -- Total reward = 0.
# Iteration #101201 -- Total reward = 0.
# Iteration #101401 -- Total reward = 0.
# Iteration #101601 -- Total reward = 0.
# Iteration #101801 -- Total reward = 0.
# Iteration #102001 -- Total reward = 0.
# Iteration #102201 -- Total reward = 0.
# Iteration #102401 -- Total reward = 1.
# Iteration #102601 -- Total reward = 0.
# Iteration #102801 -- Total reward = 0.
# Iteration #103001 -- Total reward = 0.
# Iteration #103201 -- Total reward = 0.
# Iteration #103401 -- Total reward = 0.
# Iteration #103601 -- Total reward = 1.
# Iteration #103801 -- Total reward = 1.
# Iteration #104001 -- Total reward = 0.
# Iteration #104201 -- Total reward = 0.
# Iteration #104401 -- Total reward = 0.
# Iteration #104601 -- Total reward = 1.
# Iteration #104801 -- Total reward = 0.
# Iteration #105001 -- Total reward = 0.
# Iteration #105201 -- Total reward = 0.
# Iteration #105401 -- Total reward = 1.
# Iteration #105601 -- Total reward = 0.
# Iteration #105801 -- Total reward = 0.
# Iteration #106001 -- Total reward = 1.
# Iteration #106201 -- Total reward = 1.
# Iteration #106401 -- Total reward = 1.
# Iteration #106601 -- Total reward = 0.
# Iteration #106801 -- Total reward = 0.
# Iteration #107001 -- Total reward = 1.
# Iteration #107201 -- Total reward = 1.
# Iteration #107401 -- Total reward = 1.
# Iteration #107601 -- Total reward = 0.
# Iteration #107801 -- Total reward = 0.
# Iteration #108001 -- Total reward = 0.
# Iteration #108201 -- Total reward = 0.
# Iteration #108401 -- Total reward = 0.
# Iteration #108601 -- Total reward = 0.
# Iteration #108801 -- Total reward = 0.
# Iteration #109001 -- Total reward = 1.
# Iteration #109201 -- Total reward = 0.
# Iteration #109401 -- Total reward = 1.
# Iteration #109601 -- Total reward = 1.
# Iteration #109801 -- Total reward = 0.
# Iteration #110001 -- Total reward = 1.
# Iteration #110201 -- Total reward = 1.
# Iteration #110401 -- Total reward = 0.
# Iteration #110601 -- Total reward = 1.
# Iteration #110801 -- Total reward = 0.
# Iteration #111001 -- Total reward = 0.
# Iteration #111201 -- Total reward = 0.
# Iteration #111401 -- Total reward = 0.
# Iteration #111601 -- Total reward = 0.
# Iteration #111801 -- Total reward = 0.
# Iteration #112001 -- Total reward = 0.
# Iteration #112201 -- Total reward = 0.
# Iteration #112401 -- Total reward = 0.
# Iteration #112601 -- Total reward = 1.
# Iteration #112801 -- Total reward = 0.
# Iteration #113001 -- Total reward = 0.
# Iteration #113201 -- Total reward = 1.
# Iteration #113401 -- Total reward = 0.
# Iteration #113601 -- Total reward = 0.
# Iteration #113801 -- Total reward = 1.
# Iteration #114001 -- Total reward = 1.
# Iteration #114201 -- Total reward = 0.
# Iteration #114401 -- Total reward = 1.
# Iteration #114601 -- Total reward = 0.
# Iteration #114801 -- Total reward = 0.
# Iteration #115001 -- Total reward = 0.
# Iteration #115201 -- Total reward = 0.
# Iteration #115401 -- Total reward = 0.
# Iteration #115601 -- Total reward = 0.
# Iteration #115801 -- Total reward = 0.
# Iteration #116001 -- Total reward = 0.
# Iteration #116201 -- Total reward = 0.
# Iteration #116401 -- Total reward = 0.
# Iteration #116601 -- Total reward = 0.
# Iteration #116801 -- Total reward = 0.
# Iteration #117001 -- Total reward = 0.
# Iteration #117201 -- Total reward = 0.
# Iteration #117401 -- Total reward = 0.
# Iteration #117601 -- Total reward = 0.
# Iteration #117801 -- Total reward = 0.
# Iteration #118001 -- Total reward = 0.
# Iteration #118201 -- Total reward = 1.
# Iteration #118401 -- Total reward = 0.
# Iteration #118601 -- Total reward = 0.
# Iteration #118801 -- Total reward = 1.
# Iteration #119001 -- Total reward = 0.
# Iteration #119201 -- Total reward = 1.
# Iteration #119401 -- Total reward = 0.
# Iteration #119601 -- Total reward = 0.
# Iteration #119801 -- Total reward = 0.
# Iteration #120001 -- Total reward = 0.
# Iteration #120201 -- Total reward = 0.
# Iteration #120401 -- Total reward = 1.
# Iteration #120601 -- Total reward = 1.
# Iteration #120801 -- Total reward = 0.
# Iteration #121001 -- Total reward = 0.
# Iteration #121201 -- Total reward = 0.
# Iteration #121401 -- Total reward = 0.
# Iteration #121601 -- Total reward = 1.
# Iteration #121801 -- Total reward = 0.
# Iteration #122001 -- Total reward = 0.
# Iteration #122201 -- Total reward = 0.
# Iteration #122401 -- Total reward = 0.
# Iteration #122601 -- Total reward = 1.
# Iteration #122801 -- Total reward = 0.
# Iteration #123001 -- Total reward = 0.
# Iteration #123201 -- Total reward = 1.
# Iteration #123401 -- Total reward = 0.
# Iteration #123601 -- Total reward = 0.
# Iteration #123801 -- Total reward = 0.
# Iteration #124001 -- Total reward = 0.
# Iteration #124201 -- Total reward = 0.
# Iteration #124401 -- Total reward = 0.
# Iteration #124601 -- Total reward = 0.
# Iteration #124801 -- Total reward = 0.
# Iteration #125001 -- Total reward = 0.
# Iteration #125201 -- Total reward = 0.
# Iteration #125401 -- Total reward = 0.
# Iteration #125601 -- Total reward = 1.
# Iteration #125801 -- Total reward = 0.
# Iteration #126001 -- Total reward = 0.
# Iteration #126201 -- Total reward = 0.
# Iteration #126401 -- Total reward = 1.
# Iteration #126601 -- Total reward = 0.
# Iteration #126801 -- Total reward = 1.
# Iteration #127001 -- Total reward = 1.
# Iteration #127201 -- Total reward = 1.
# Iteration #127401 -- Total reward = 0.
# Iteration #127601 -- Total reward = 1.
# Iteration #127801 -- Total reward = 1.
# Iteration #128001 -- Total reward = 1.
# Iteration #128201 -- Total reward = 1.
# Iteration #128401 -- Total reward = 0.
# Iteration #128601 -- Total reward = 0.
# Iteration #128801 -- Total reward = 1.
# Iteration #129001 -- Total reward = 0.
# Iteration #129201 -- Total reward = 1.
# Iteration #129401 -- Total reward = 1.
# Iteration #129601 -- Total reward = 0.
# Iteration #129801 -- Total reward = 0.
# Iteration #130001 -- Total reward = 0.
# Iteration #130201 -- Total reward = 0.
# Iteration #130401 -- Total reward = 1.
# Iteration #130601 -- Total reward = 0.
# Iteration #130801 -- Total reward = 0.
# Iteration #131001 -- Total reward = 1.
# Iteration #131201 -- Total reward = 0.
# Iteration #131401 -- Total reward = 0.
# Iteration #131601 -- Total reward = 1.
# Iteration #131801 -- Total reward = 0.
# Iteration #132001 -- Total reward = 0.
# Iteration #132201 -- Total reward = 0.
# Iteration #132401 -- Total reward = 1.
# Iteration #132601 -- Total reward = 0.
# Iteration #132801 -- Total reward = 0.
# Iteration #133001 -- Total reward = 0.
# Iteration #133201 -- Total reward = 0.
# Iteration #133401 -- Total reward = 0.
# Iteration #133601 -- Total reward = 1.
# Iteration #133801 -- Total reward = 0.
# Iteration #134001 -- Total reward = 1.
# Iteration #134201 -- Total reward = 0.
# Iteration #134401 -- Total reward = 0.
# Iteration #134601 -- Total reward = 1.
# Iteration #134801 -- Total reward = 0.
# Iteration #135001 -- Total reward = 0.
# Iteration #135201 -- Total reward = 1.
# Iteration #135401 -- Total reward = 1.
# Iteration #135601 -- Total reward = 0.
# Iteration #135801 -- Total reward = 0.
# Iteration #136001 -- Total reward = 1.
# Iteration #136201 -- Total reward = 1.
# Iteration #136401 -- Total reward = 0.
# Iteration #136601 -- Total reward = 1.
# Iteration #136801 -- Total reward = 1.
# Iteration #137001 -- Total reward = 1.
# Iteration #137201 -- Total reward = 0.
# Iteration #137401 -- Total reward = 0.
# Iteration #137601 -- Total reward = 1.
# Iteration #137801 -- Total reward = 0.
# Iteration #138001 -- Total reward = 0.
# Iteration #138201 -- Total reward = 0.
# Iteration #138401 -- Total reward = 1.
# Iteration #138601 -- Total reward = 0.
# Iteration #138801 -- Total reward = 1.
# Iteration #139001 -- Total reward = 1.
# Iteration #139201 -- Total reward = 0.
# Iteration #139401 -- Total reward = 1.
# Iteration #139601 -- Total reward = 0.
# Iteration #139801 -- Total reward = 0.
# Iteration #140001 -- Total reward = 0.
# Iteration #140201 -- Total reward = 0.
# Iteration #140401 -- Total reward = 1.
# Iteration #140601 -- Total reward = 1.
# Iteration #140801 -- Total reward = 0.
# Iteration #141001 -- Total reward = 0.
# Iteration #141201 -- Total reward = 0.
# Iteration #141401 -- Total reward = 1.
# Iteration #141601 -- Total reward = 0.
# Iteration #141801 -- Total reward = 0.
# Iteration #142001 -- Total reward = 0.
# Iteration #142201 -- Total reward = 1.
# Iteration #142401 -- Total reward = 0.
# Iteration #142601 -- Total reward = 1.
# Iteration #142801 -- Total reward = 1.
# Iteration #143001 -- Total reward = 1.
# Iteration #143201 -- Total reward = 1.
# Iteration #143401 -- Total reward = 0.
# Iteration #143601 -- Total reward = 1.
# Iteration #143801 -- Total reward = 1.
# Iteration #144001 -- Total reward = 1.
# Iteration #144201 -- Total reward = 1.
# Iteration #144401 -- Total reward = 0.
# Iteration #144601 -- Total reward = 1.
# Iteration #144801 -- Total reward = 1.
# Iteration #145001 -- Total reward = 1.
# Iteration #145201 -- Total reward = 0.
# Iteration #145401 -- Total reward = 0.
# Iteration #145601 -- Total reward = 0.
# Iteration #145801 -- Total reward = 0.
# Iteration #146001 -- Total reward = 0.
# Iteration #146201 -- Total reward = 1.
# Iteration #146401 -- Total reward = 0.
# Iteration #146601 -- Total reward = 0.
# Iteration #146801 -- Total reward = 0.
# Iteration #147001 -- Total reward = 1.
# Iteration #147201 -- Total reward = 0.
# Iteration #147401 -- Total reward = 0.
# Iteration #147601 -- Total reward = 0.
# Iteration #147801 -- Total reward = 1.
# Iteration #148001 -- Total reward = 0.
# Iteration #148201 -- Total reward = 0.
# Iteration #148401 -- Total reward = 1.
# Iteration #148601 -- Total reward = 0.
# Iteration #148801 -- Total reward = 1.
# Iteration #149001 -- Total reward = 1.
# Iteration #149201 -- Total reward = 0.
# Iteration #149401 -- Total reward = 0.
# Iteration #149601 -- Total reward = 1.
# Iteration #149801 -- Total reward = 0.
# Iteration #150001 -- Total reward = 0.
# Iteration #150201 -- Total reward = 1.
# Iteration #150401 -- Total reward = 0.
# Iteration #150601 -- Total reward = 1.
# Iteration #150801 -- Total reward = 1.
# Iteration #151001 -- Total reward = 1.
# Iteration #151201 -- Total reward = 0.
# Iteration #151401 -- Total reward = 1.
# Iteration #151601 -- Total reward = 0.
# Iteration #151801 -- Total reward = 0.
# Iteration #152001 -- Total reward = 0.
# Iteration #152201 -- Total reward = 1.
# Iteration #152401 -- Total reward = 0.
# Iteration #152601 -- Total reward = 1.
# Iteration #152801 -- Total reward = 0.
# Iteration #153001 -- Total reward = 1.
# Iteration #153201 -- Total reward = 0.
# Iteration #153401 -- Total reward = 0.
# Iteration #153601 -- Total reward = 0.
# Iteration #153801 -- Total reward = 1.
# Iteration #154001 -- Total reward = 0.
# Iteration #154201 -- Total reward = 0.
# Iteration #154401 -- Total reward = 1.
# Iteration #154601 -- Total reward = 1.
# Iteration #154801 -- Total reward = 0.
# Iteration #155001 -- Total reward = 1.
# Iteration #155201 -- Total reward = 1.
# Iteration #155401 -- Total reward = 0.
# Iteration #155601 -- Total reward = 0.
# Iteration #155801 -- Total reward = 1.
# Iteration #156001 -- Total reward = 1.
# Iteration #156201 -- Total reward = 0.
# Iteration #156401 -- Total reward = 1.
# Iteration #156601 -- Total reward = 1.
# Iteration #156801 -- Total reward = 0.
# Iteration #157001 -- Total reward = 1.
# Iteration #157201 -- Total reward = 1.
# Iteration #157401 -- Total reward = 1.
# Iteration #157601 -- Total reward = 0.
# Iteration #157801 -- Total reward = 0.
# Iteration #158001 -- Total reward = 0.
# Iteration #158201 -- Total reward = 0.
# Iteration #158401 -- Total reward = 0.
# Iteration #158601 -- Total reward = 0.
# Iteration #158801 -- Total reward = 1.
# Iteration #159001 -- Total reward = 1.
# Iteration #159201 -- Total reward = 1.
# Iteration #159401 -- Total reward = 0.
# Iteration #159601 -- Total reward = 1.
# Iteration #159801 -- Total reward = 0.
# Iteration #160001 -- Total reward = 0.
# Iteration #160201 -- Total reward = 0.
# Iteration #160401 -- Total reward = 0.
# Iteration #160601 -- Total reward = 0.
# Iteration #160801 -- Total reward = 1.
# Iteration #161001 -- Total reward = 1.
# Iteration #161201 -- Total reward = 1.
# Iteration #161401 -- Total reward = 0.
# Iteration #161601 -- Total reward = 1.
# Iteration #161801 -- Total reward = 1.
# Iteration #162001 -- Total reward = 1.
# Iteration #162201 -- Total reward = 0.
# Iteration #162401 -- Total reward = 0.
# Iteration #162601 -- Total reward = 0.
# Iteration #162801 -- Total reward = 1.
# Iteration #163001 -- Total reward = 0.
# Iteration #163201 -- Total reward = 1.
# Iteration #163401 -- Total reward = 0.
# Iteration #163601 -- Total reward = 0.
# Iteration #163801 -- Total reward = 0.
# Iteration #164001 -- Total reward = 0.
# Iteration #164201 -- Total reward = 1.
# Iteration #164401 -- Total reward = 0.
# Iteration #164601 -- Total reward = 1.
# Iteration #164801 -- Total reward = 0.
# Iteration #165001 -- Total reward = 1.
# Iteration #165201 -- Total reward = 1.
# Iteration #165401 -- Total reward = 0.
# Iteration #165601 -- Total reward = 0.
# Iteration #165801 -- Total reward = 1.
# Iteration #166001 -- Total reward = 0.
# Iteration #166201 -- Total reward = 0.
# Iteration #166401 -- Total reward = 0.
# Iteration #166601 -- Total reward = 0.
# Iteration #166801 -- Total reward = 0.
# Iteration #167001 -- Total reward = 0.
# Iteration #167201 -- Total reward = 0.
# Iteration #167401 -- Total reward = 1.
# Iteration #167601 -- Total reward = 0.
# Iteration #167801 -- Total reward = 1.
# Iteration #168001 -- Total reward = 0.
# Iteration #168201 -- Total reward = 1.
# Iteration #168401 -- Total reward = 0.
# Iteration #168601 -- Total reward = 0.
# Iteration #168801 -- Total reward = 0.
# Iteration #169001 -- Total reward = 1.
# Iteration #169201 -- Total reward = 0.
# Iteration #169401 -- Total reward = 0.
# Iteration #169601 -- Total reward = 0.
# Iteration #169801 -- Total reward = 1.
# Iteration #170001 -- Total reward = 1.
# Iteration #170201 -- Total reward = 0.
# Iteration #170401 -- Total reward = 1.
# Iteration #170601 -- Total reward = 0.
# Iteration #170801 -- Total reward = 1.
# Iteration #171001 -- Total reward = 1.
# Iteration #171201 -- Total reward = 0.
# Iteration #171401 -- Total reward = 0.
# Iteration #171601 -- Total reward = 0.
# Iteration #171801 -- Total reward = 1.
# Iteration #172001 -- Total reward = 0.
# Iteration #172201 -- Total reward = 1.
# Iteration #172401 -- Total reward = 0.
# Iteration #172601 -- Total reward = 1.
# Iteration #172801 -- Total reward = 0.
# Iteration #173001 -- Total reward = 0.
# Iteration #173201 -- Total reward = 0.
# Iteration #173401 -- Total reward = 0.
# Iteration #173601 -- Total reward = 1.
# Iteration #173801 -- Total reward = 0.
# Iteration #174001 -- Total reward = 0.
# Iteration #174201 -- Total reward = 0.
# Iteration #174401 -- Total reward = 0.
# Iteration #174601 -- Total reward = 1.
# Iteration #174801 -- Total reward = 0.
# Iteration #175001 -- Total reward = 0.
# Iteration #175201 -- Total reward = 0.
# Iteration #175401 -- Total reward = 0.
# Iteration #175601 -- Total reward = 0.
# Iteration #175801 -- Total reward = 0.
# Iteration #176001 -- Total reward = 0.
# Iteration #176201 -- Total reward = 0.
# Iteration #176401 -- Total reward = 1.
# Iteration #176601 -- Total reward = 1.
# Iteration #176801 -- Total reward = 1.
# Iteration #177001 -- Total reward = 0.
# Iteration #177201 -- Total reward = 0.
# Iteration #177401 -- Total reward = 0.
# Iteration #177601 -- Total reward = 0.
# Iteration #177801 -- Total reward = 0.
# Iteration #178001 -- Total reward = 1.
# Iteration #178201 -- Total reward = 1.
# Iteration #178401 -- Total reward = 0.
# Iteration #178601 -- Total reward = 0.
# Iteration #178801 -- Total reward = 1.
# Iteration #179001 -- Total reward = 0.
# Iteration #179201 -- Total reward = 0.
# Iteration #179401 -- Total reward = 0.
# Iteration #179601 -- Total reward = 0.
# Iteration #179801 -- Total reward = 0.
# Iteration #180001 -- Total reward = 0.
# Iteration #180201 -- Total reward = 0.
# Iteration #180401 -- Total reward = 0.
# Iteration #180601 -- Total reward = 1.
# Iteration #180801 -- Total reward = 0.
# Iteration #181001 -- Total reward = 1.
# Iteration #181201 -- Total reward = 1.
# Iteration #181401 -- Total reward = 1.
# Iteration #181601 -- Total reward = 0.
# Iteration #181801 -- Total reward = 1.
# Iteration #182001 -- Total reward = 1.
# Iteration #182201 -- Total reward = 1.
# Iteration #182401 -- Total reward = 0.
# Iteration #182601 -- Total reward = 0.
# Iteration #182801 -- Total reward = 0.
# Iteration #183001 -- Total reward = 0.
# Iteration #183201 -- Total reward = 0.
# Iteration #183401 -- Total reward = 1.
# Iteration #183601 -- Total reward = 0.
# Iteration #183801 -- Total reward = 0.
# Iteration #184001 -- Total reward = 1.
# Iteration #184201 -- Total reward = 1.
# Iteration #184401 -- Total reward = 0.
# Iteration #184601 -- Total reward = 0.
# Iteration #184801 -- Total reward = 1.
# Iteration #185001 -- Total reward = 1.
# Iteration #185201 -- Total reward = 1.
# Iteration #185401 -- Total reward = 0.
# Iteration #185601 -- Total reward = 1.
# Iteration #185801 -- Total reward = 0.
# Iteration #186001 -- Total reward = 1.
# Iteration #186201 -- Total reward = 0.
# Iteration #186401 -- Total reward = 1.
# Iteration #186601 -- Total reward = 1.
# Iteration #186801 -- Total reward = 0.
# Iteration #187001 -- Total reward = 0.
# Iteration #187201 -- Total reward = 1.
# Iteration #187401 -- Total reward = 0.
# Iteration #187601 -- Total reward = 0.
# Iteration #187801 -- Total reward = 1.
# Iteration #188001 -- Total reward = 1.
# Iteration #188201 -- Total reward = 0.
# Iteration #188401 -- Total reward = 1.
# Iteration #188601 -- Total reward = 1.
# Iteration #188801 -- Total reward = 0.
# Iteration #189001 -- Total reward = 0.
# Iteration #189201 -- Total reward = 0.
# Iteration #189401 -- Total reward = 0.
# Iteration #189601 -- Total reward = 1.
# Iteration #189801 -- Total reward = 0.
# Iteration #190001 -- Total reward = 0.
# Iteration #190201 -- Total reward = 1.
# Iteration #190401 -- Total reward = 0.
# Iteration #190601 -- Total reward = 0.
# Iteration #190801 -- Total reward = 1.
# Iteration #191001 -- Total reward = 0.
# Iteration #191201 -- Total reward = 0.
# Iteration #191401 -- Total reward = 0.
# Iteration #191601 -- Total reward = 1.
# Iteration #191801 -- Total reward = 0.
# Iteration #192001 -- Total reward = 0.
# Iteration #192201 -- Total reward = 1.
# Iteration #192401 -- Total reward = 1.
# Iteration #192601 -- Total reward = 1.
# Iteration #192801 -- Total reward = 0.
# Iteration #193001 -- Total reward = 0.
# Iteration #193201 -- Total reward = 0.
# Iteration #193401 -- Total reward = 0.
# Iteration #193601 -- Total reward = 0.
# Iteration #193801 -- Total reward = 1.
# Iteration #194001 -- Total reward = 1.
# Iteration #194201 -- Total reward = 0.
# Iteration #194401 -- Total reward = 1.
# Iteration #194601 -- Total reward = 1.
# Iteration #194801 -- Total reward = 0.
# Iteration #195001 -- Total reward = 1.
# Iteration #195201 -- Total reward = 0.
# Iteration #195401 -- Total reward = 0.
# Iteration #195601 -- Total reward = 0.
# Iteration #195801 -- Total reward = 0.
# Iteration #196001 -- Total reward = 1.
# Iteration #196201 -- Total reward = 0.
# Iteration #196401 -- Total reward = 0.
# Iteration #196601 -- Total reward = 1.
# Iteration #196801 -- Total reward = 0.
# Iteration #197001 -- Total reward = 1.
# Iteration #197201 -- Total reward = 1.
# Iteration #197401 -- Total reward = 0.
# Iteration #197601 -- Total reward = 0.
# Iteration #197801 -- Total reward = 0.
# Iteration #198001 -- Total reward = 1.
# Iteration #198201 -- Total reward = 1.
# Iteration #198401 -- Total reward = 1.
# Iteration #198601 -- Total reward = 0.
# Iteration #198801 -- Total reward = 0.
# Iteration #199001 -- Total reward = 1.
# Iteration #199201 -- Total reward = 1.
# Iteration #199401 -- Total reward = 1.
# Iteration #199601 -- Total reward = 0.
# Iteration #199801 -- Total reward = 0.
# Iteration #200001 -- Total reward = 0.
# Iteration #200201 -- Total reward = 0.
# Iteration #200401 -- Total reward = 0.
# Iteration #200601 -- Total reward = 1.
# Iteration #200801 -- Total reward = 1.
# Iteration #201001 -- Total reward = 0.
# Iteration #201201 -- Total reward = 0.
# Iteration #201401 -- Total reward = 1.
# Iteration #201601 -- Total reward = 0.
# Iteration #201801 -- Total reward = 0.
# Iteration #202001 -- Total reward = 1.
# Iteration #202201 -- Total reward = 1.
# Iteration #202401 -- Total reward = 0.
# Iteration #202601 -- Total reward = 0.
# Iteration #202801 -- Total reward = 1.
# Iteration #203001 -- Total reward = 1.
# Iteration #203201 -- Total reward = 1.
# Iteration #203401 -- Total reward = 0.
# Iteration #203601 -- Total reward = 0.
# Iteration #203801 -- Total reward = 0.
# Iteration #204001 -- Total reward = 0.
# Iteration #204201 -- Total reward = 0.
# Iteration #204401 -- Total reward = 1.
# Iteration #204601 -- Total reward = 1.
# Iteration #204801 -- Total reward = 1.
# Iteration #205001 -- Total reward = 1.
# Iteration #205201 -- Total reward = 1.
# Iteration #205401 -- Total reward = 1.
# Iteration #205601 -- Total reward = 1.
# Iteration #205801 -- Total reward = 0.
# Iteration #206001 -- Total reward = 1.
# Iteration #206201 -- Total reward = 0.
# Iteration #206401 -- Total reward = 0.
# Iteration #206601 -- Total reward = 1.
# Iteration #206801 -- Total reward = 1.
# Iteration #207001 -- Total reward = 1.
# Iteration #207201 -- Total reward = 0.
# Iteration #207401 -- Total reward = 0.
# Iteration #207601 -- Total reward = 1.
# Iteration #207801 -- Total reward = 1.
# Iteration #208001 -- Total reward = 1.
# Iteration #208201 -- Total reward = 1.
# Iteration #208401 -- Total reward = 0.
# Iteration #208601 -- Total reward = 1.
# Iteration #208801 -- Total reward = 0.
# Iteration #209001 -- Total reward = 0.
# Iteration #209201 -- Total reward = 0.
# Iteration #209401 -- Total reward = 0.
# Iteration #209601 -- Total reward = 0.
# Iteration #209801 -- Total reward = 0.
# Iteration #210001 -- Total reward = 0.
# Iteration #210201 -- Total reward = 0.
# Iteration #210401 -- Total reward = 0.
# Iteration #210601 -- Total reward = 0.
# Iteration #210801 -- Total reward = 0.
# Iteration #211001 -- Total reward = 1.
# Iteration #211201 -- Total reward = 0.
# Iteration #211401 -- Total reward = 1.
# Iteration #211601 -- Total reward = 1.
# Iteration #211801 -- Total reward = 1.
# Iteration #212001 -- Total reward = 1.
# Iteration #212201 -- Total reward = 1.
# Iteration #212401 -- Total reward = 1.
# Iteration #212601 -- Total reward = 1.
# Iteration #212801 -- Total reward = 1.
# Iteration #213001 -- Total reward = 1.
# Iteration #213201 -- Total reward = 1.
# Iteration #213401 -- Total reward = 1.
# Iteration #213601 -- Total reward = 0.
# Iteration #213801 -- Total reward = 0.
# Iteration #214001 -- Total reward = 1.
# Iteration #214201 -- Total reward = 1.
# Iteration #214401 -- Total reward = 0.
# Iteration #214601 -- Total reward = 0.
# Iteration #214801 -- Total reward = 0.
# Iteration #215001 -- Total reward = 1.
# Iteration #215201 -- Total reward = 0.
# Iteration #215401 -- Total reward = 1.
# Iteration #215601 -- Total reward = 0.
# Iteration #215801 -- Total reward = 0.
# Iteration #216001 -- Total reward = 0.
# Iteration #216201 -- Total reward = 0.
# Iteration #216401 -- Total reward = 1.
# Iteration #216601 -- Total reward = 1.
# Iteration #216801 -- Total reward = 1.
# Iteration #217001 -- Total reward = 0.
# Iteration #217201 -- Total reward = 0.
# Iteration #217401 -- Total reward = 0.
# Iteration #217601 -- Total reward = 1.
# Iteration #217801 -- Total reward = 0.
# Iteration #218001 -- Total reward = 1.
# Iteration #218201 -- Total reward = 1.
# Iteration #218401 -- Total reward = 0.
# Iteration #218601 -- Total reward = 0.
# Iteration #218801 -- Total reward = 0.
# Iteration #219001 -- Total reward = 1.
# Iteration #219201 -- Total reward = 0.
# Iteration #219401 -- Total reward = 0.
# Iteration #219601 -- Total reward = 0.
# Iteration #219801 -- Total reward = 1.
# Iteration #220001 -- Total reward = 1.
# Iteration #220201 -- Total reward = 0.
# Iteration #220401 -- Total reward = 0.
# Iteration #220601 -- Total reward = 0.
# Iteration #220801 -- Total reward = 0.
# Iteration #221001 -- Total reward = 1.
# Iteration #221201 -- Total reward = 0.
# Iteration #221401 -- Total reward = 0.
# Iteration #221601 -- Total reward = 1.
# Iteration #221801 -- Total reward = 0.
# Iteration #222001 -- Total reward = 0.
# Iteration #222201 -- Total reward = 1.
# Iteration #222401 -- Total reward = 1.
# Iteration #222601 -- Total reward = 0.
# Iteration #222801 -- Total reward = 0.
# Iteration #223001 -- Total reward = 1.
# Iteration #223201 -- Total reward = 0.
# Iteration #223401 -- Total reward = 0.
# Iteration #223601 -- Total reward = 0.
# Iteration #223801 -- Total reward = 0.
# Iteration #224001 -- Total reward = 1.
# Iteration #224201 -- Total reward = 0.
# Iteration #224401 -- Total reward = 0.
# Iteration #224601 -- Total reward = 1.
# Iteration #224801 -- Total reward = 1.
# Iteration #225001 -- Total reward = 1.
# Iteration #225201 -- Total reward = 1.
# Iteration #225401 -- Total reward = 0.
# Iteration #225601 -- Total reward = 0.
# Iteration #225801 -- Total reward = 0.
# Iteration #226001 -- Total reward = 0.
# Iteration #226201 -- Total reward = 1.
# Iteration #226401 -- Total reward = 1.
# Iteration #226601 -- Total reward = 1.
# Iteration #226801 -- Total reward = 0.
# Iteration #227001 -- Total reward = 0.
# Iteration #227201 -- Total reward = 1.
# Iteration #227401 -- Total reward = 0.
# Iteration #227601 -- Total reward = 1.
# Iteration #227801 -- Total reward = 1.
# Iteration #228001 -- Total reward = 0.
# Iteration #228201 -- Total reward = 0.
# Iteration #228401 -- Total reward = 0.
# Iteration #228601 -- Total reward = 0.
# Iteration #228801 -- Total reward = 1.
# Iteration #229001 -- Total reward = 0.
# Iteration #229201 -- Total reward = 0.
# Iteration #229401 -- Total reward = 0.
# Iteration #229601 -- Total reward = 0.
# Iteration #229801 -- Total reward = 1.
# Iteration #230001 -- Total reward = 0.
# Iteration #230201 -- Total reward = 0.
# Iteration #230401 -- Total reward = 0.
# Iteration #230601 -- Total reward = 0.
# Iteration #230801 -- Total reward = 0.
# Iteration #231001 -- Total reward = 0.
# Iteration #231201 -- Total reward = 0.
# Iteration #231401 -- Total reward = 0.
# Iteration #231601 -- Total reward = 1.
# Iteration #231801 -- Total reward = 1.
# Iteration #232001 -- Total reward = 0.
# Iteration #232201 -- Total reward = 0.
# Iteration #232401 -- Total reward = 0.
# Iteration #232601 -- Total reward = 1.
# Iteration #232801 -- Total reward = 0.
# Iteration #233001 -- Total reward = 1.
# Iteration #233201 -- Total reward = 1.
# Iteration #233401 -- Total reward = 1.
# Iteration #233601 -- Total reward = 0.
# Iteration #233801 -- Total reward = 0.
# Iteration #234001 -- Total reward = 0.
# Iteration #234201 -- Total reward = 0.
# Iteration #234401 -- Total reward = 0.
# Iteration #234601 -- Total reward = 0.
# Iteration #234801 -- Total reward = 1.
# Iteration #235001 -- Total reward = 0.
# Iteration #235201 -- Total reward = 0.
# Iteration #235401 -- Total reward = 0.
# Iteration #235601 -- Total reward = 0.
# Iteration #235801 -- Total reward = 0.
# Iteration #236001 -- Total reward = 1.
# Iteration #236201 -- Total reward = 0.
# Iteration #236401 -- Total reward = 1.
# Iteration #236601 -- Total reward = 1.
# Iteration #236801 -- Total reward = 0.
# Iteration #237001 -- Total reward = 0.
# Iteration #237201 -- Total reward = 1.
# Iteration #237401 -- Total reward = 0.
# Iteration #237601 -- Total reward = 1.
# Iteration #237801 -- Total reward = 0.
# Iteration #238001 -- Total reward = 0.
# Iteration #238201 -- Total reward = 1.
# Iteration #238401 -- Total reward = 0.
# Iteration #238601 -- Total reward = 1.
# Iteration #238801 -- Total reward = 0.
# Iteration #239001 -- Total reward = 0.
# Iteration #239201 -- Total reward = 0.
# Iteration #239401 -- Total reward = 1.
# Iteration #239601 -- Total reward = 0.
# Iteration #239801 -- Total reward = 0.
# Iteration #240001 -- Total reward = 0.
# Iteration #240201 -- Total reward = 1.
# Iteration #240401 -- Total reward = 1.
# Iteration #240601 -- Total reward = 0.
# Iteration #240801 -- Total reward = 0.
# Iteration #241001 -- Total reward = 0.
# Iteration #241201 -- Total reward = 1.
# Iteration #241401 -- Total reward = 0.
# Iteration #241601 -- Total reward = 1.
# Iteration #241801 -- Total reward = 1.
# Iteration #242001 -- Total reward = 1.
# Iteration #242201 -- Total reward = 1.
# Iteration #242401 -- Total reward = 0.
# Iteration #242601 -- Total reward = 0.
# Iteration #242801 -- Total reward = 0.
# Iteration #243001 -- Total reward = 1.
# Iteration #243201 -- Total reward = 0.
# Iteration #243401 -- Total reward = 1.
# Iteration #243601 -- Total reward = 0.
# Iteration #243801 -- Total reward = 1.
# Iteration #244001 -- Total reward = 0.
# Iteration #244201 -- Total reward = 0.
# Iteration #244401 -- Total reward = 1.
# Iteration #244601 -- Total reward = 0.
# Iteration #244801 -- Total reward = 0.
# Iteration #245001 -- Total reward = 0.
# Iteration #245201 -- Total reward = 1.
# Iteration #245401 -- Total reward = 0.
# Iteration #245601 -- Total reward = 1.
# Iteration #245801 -- Total reward = 0.
# Iteration #246001 -- Total reward = 0.
# Iteration #246201 -- Total reward = 1.
# Iteration #246401 -- Total reward = 0.
# Iteration #246601 -- Total reward = 0.
# Iteration #246801 -- Total reward = 1.
# Iteration #247001 -- Total reward = 0.
# Iteration #247201 -- Total reward = 1.
# Iteration #247401 -- Total reward = 0.
# Iteration #247601 -- Total reward = 0.
# Iteration #247801 -- Total reward = 1.
# Iteration #248001 -- Total reward = 1.
# Iteration #248201 -- Total reward = 1.
# Iteration #248401 -- Total reward = 1.
# Iteration #248601 -- Total reward = 0.
# ...
# Iteration #920401 -- Total reward = 0.
# Iteration #920601 -- Total reward = 0.
# Iteration #920801 -- Total reward = 0.
# Iteration #921001 -- Total reward = 0.
# Iteration #921201 -- Total reward = 1.
# Iteration #921401 -- Total reward = 0.
# Iteration #921601 -- Total reward = 0.
# Iteration #921801 -- Total reward = 0.
# Iteration #922001 -- Total reward = 1.
# Iteration #922201 -- Total reward = 0.
# Iteration #922401 -- Total reward = 1.
# Iteration #922601 -- Total reward = 0.
# Iteration #922801 -- Total reward = 0.
# Iteration #923001 -- Total reward = 0.
# Iteration #923201 -- Total reward = 0.
# Iteration #923401 -- Total reward = 0.
# Iteration #923601 -- Total reward = 1.
# Iteration #923801 -- Total reward = 0.
# Iteration #924001 -- Total reward = 1.
# Iteration #924201 -- Total reward = 1.
# Iteration #924401 -- Total reward = 1.
# Iteration #924601 -- Total reward = 0.
# Iteration #924801 -- Total reward = 0.
# Iteration #925001 -- Total reward = 0.
# Iteration #925201 -- Total reward = 1.
# Iteration #925401 -- Total reward = 0.
# Iteration #925601 -- Total reward = 1.
# Iteration #925801 -- Total reward = 0.
# Iteration #926001 -- Total reward = 0.
# Iteration #926201 -- Total reward = 1.
# Iteration #926401 -- Total reward = 1.
# Iteration #926601 -- Total reward = 1.
# Iteration #926801 -- Total reward = 1.
# Iteration #927001 -- Total reward = 1.
# Iteration #927201 -- Total reward = 0.
# Iteration #927401 -- Total reward = 1.
# Iteration #927601 -- Total reward = 0.
# Iteration #927801 -- Total reward = 0.
# Iteration #928001 -- Total reward = 0.
# Iteration #928201 -- Total reward = 1.
# Iteration #928401 -- Total reward = 0.
# Iteration #928601 -- Total reward = 0.
# Iteration #928801 -- Total reward = 1.
# Iteration #929001 -- Total reward = 0.
# Iteration #929201 -- Total reward = 0.
# Iteration #929401 -- Total reward = 1.
# Iteration #929601 -- Total reward = 0.
# Iteration #929801 -- Total reward = 1.
# Iteration #930001 -- Total reward = 1.
# Iteration #930201 -- Total reward = 0.
# Iteration #930401 -- Total reward = 0.
# Iteration #930601 -- Total reward = 1.
# Iteration #930801 -- Total reward = 1.
# Iteration #931001 -- Total reward = 1.
# Iteration #931201 -- Total reward = 0.
# Iteration #931401 -- Total reward = 1.
# Iteration #931601 -- Total reward = 0.
# Iteration #931801 -- Total reward = 0.
# Iteration #932001 -- Total reward = 1.
# Iteration #932201 -- Total reward = 1.
# Iteration #932401 -- Total reward = 1.
# Iteration #932601 -- Total reward = 1.
# Iteration #932801 -- Total reward = 0.
# Iteration #933001 -- Total reward = 0.
# Iteration #933201 -- Total reward = 0.
# Iteration #933401 -- Total reward = 0.
# Iteration #933601 -- Total reward = 1.
# Iteration #933801 -- Total reward = 0.
# Iteration #934001 -- Total reward = 0.
# Iteration #934201 -- Total reward = 1.
# Iteration #934401 -- Total reward = 0.
# Iteration #934601 -- Total reward = 1.
# Iteration #934801 -- Total reward = 0.
# Iteration #935001 -- Total reward = 1.
# Iteration #935201 -- Total reward = 0.
# Iteration #935401 -- Total reward = 0.
# Iteration #935601 -- Total reward = 0.
# Iteration #935801 -- Total reward = 1.
# Iteration #936001 -- Total reward = 1.
# Iteration #936201 -- Total reward = 0.
# Iteration #936401 -- Total reward = 1.
# Iteration #936601 -- Total reward = 0.
# Iteration #936801 -- Total reward = 1.
# Iteration #937001 -- Total reward = 1.
# Iteration #937201 -- Total reward = 1.
# Iteration #937401 -- Total reward = 0.
# Iteration #937601 -- Total reward = 0.
# Iteration #937801 -- Total reward = 0.
# Iteration #938001 -- Total reward = 0.
# Iteration #938201 -- Total reward = 1.
# Iteration #938401 -- Total reward = 0.
# Iteration #938601 -- Total reward = 0.
# Iteration #938801 -- Total reward = 0.
# Iteration #939001 -- Total reward = 0.
# Iteration #939201 -- Total reward = 0.
# Iteration #939401 -- Total reward = 0.
# Iteration #939601 -- Total reward = 0.
# Iteration #939801 -- Total reward = 0.
# Iteration #940001 -- Total reward = 0.
# Iteration #940201 -- Total reward = 0.
# Iteration #940401 -- Total reward = 1.
# Iteration #940601 -- Total reward = 1.
# Iteration #940801 -- Total reward = 1.
# Iteration #941001 -- Total reward = 0.
# Iteration #941201 -- Total reward = 0.
# Iteration #941401 -- Total reward = 0.
# Iteration #941601 -- Total reward = 0.
# Iteration #941801 -- Total reward = 0.
# Iteration #942001 -- Total reward = 0.
# Iteration #942201 -- Total reward = 0.
# Iteration #942401 -- Total reward = 0.
# Iteration #942601 -- Total reward = 0.
# Iteration #942801 -- Total reward = 1.
# Iteration #943001 -- Total reward = 0.
# Iteration #943201 -- Total reward = 0.
# Iteration #943401 -- Total reward = 1.
# Iteration #943601 -- Total reward = 1.
# Iteration #943801 -- Total reward = 0.
# Iteration #944001 -- Total reward = 1.
# Iteration #944201 -- Total reward = 0.
# Iteration #944401 -- Total reward = 0.
# Iteration #944601 -- Total reward = 1.
# Iteration #944801 -- Total reward = 1.
# Iteration #945001 -- Total reward = 0.
# Iteration #945201 -- Total reward = 0.
# Iteration #945401 -- Total reward = 0.
# Iteration #945601 -- Total reward = 1.
# Iteration #945801 -- Total reward = 1.
# Iteration #946001 -- Total reward = 0.
# Iteration #946201 -- Total reward = 1.
# Iteration #946401 -- Total reward = 1.
# Iteration #946601 -- Total reward = 0.
# Iteration #946801 -- Total reward = 0.
# Iteration #947001 -- Total reward = 0.
# Iteration #947201 -- Total reward = 0.
# Iteration #947401 -- Total reward = 1.
# Iteration #947601 -- Total reward = 0.
# Iteration #947801 -- Total reward = 0.
# Iteration #948001 -- Total reward = 1.
# Iteration #948201 -- Total reward = 1.
# Iteration #948401 -- Total reward = 0.
# Iteration #948601 -- Total reward = 1.
# Iteration #948801 -- Total reward = 0.
# Iteration #949001 -- Total reward = 1.
# Iteration #949201 -- Total reward = 0.
# Iteration #949401 -- Total reward = 0.
# Iteration #949601 -- Total reward = 0.
# Iteration #949801 -- Total reward = 1.
# Iteration #950001 -- Total reward = 1.
# Iteration #950201 -- Total reward = 0.
# Iteration #950401 -- Total reward = 1.
# Iteration #950601 -- Total reward = 0.
# Iteration #950801 -- Total reward = 1.
# Iteration #951001 -- Total reward = 1.
# Iteration #951201 -- Total reward = 1.
# Iteration #951401 -- Total reward = 0.
# Iteration #951601 -- Total reward = 0.
# Iteration #951801 -- Total reward = 1.
# Iteration #952001 -- Total reward = 0.
# Iteration #952201 -- Total reward = 0.
# Iteration #952401 -- Total reward = 0.
# Iteration #952601 -- Total reward = 0.
# Iteration #952801 -- Total reward = 0.
# Iteration #953001 -- Total reward = 0.
# Iteration #953201 -- Total reward = 1.
# Iteration #953401 -- Total reward = 1.
# Iteration #953601 -- Total reward = 1.
# Iteration #953801 -- Total reward = 0.
# Iteration #954001 -- Total reward = 0.
# Iteration #954201 -- Total reward = 0.
# Iteration #954401 -- Total reward = 1.
# Iteration #954601 -- Total reward = 1.
# Iteration #954801 -- Total reward = 0.
# Iteration #955001 -- Total reward = 0.
# Iteration #955201 -- Total reward = 0.
# Iteration #955401 -- Total reward = 1.
# Iteration #955601 -- Total reward = 0.
# Iteration #955801 -- Total reward = 0.
# Iteration #956001 -- Total reward = 0.
# Iteration #956201 -- Total reward = 0.
# Iteration #956401 -- Total reward = 1.
# Iteration #956601 -- Total reward = 0.
# Iteration #956801 -- Total reward = 1.
# Iteration #957001 -- Total reward = 1.
# Iteration #957201 -- Total reward = 0.
# Iteration #957401 -- Total reward = 0.
# Iteration #957601 -- Total reward = 0.
# Iteration #957801 -- Total reward = 0.
# Iteration #958001 -- Total reward = 1.
# Iteration #958201 -- Total reward = 0.
# Iteration #958401 -- Total reward = 0.
# Iteration #958601 -- Total reward = 0.
# Iteration #958801 -- Total reward = 1.
# Iteration #959001 -- Total reward = 0.
# Iteration #959201 -- Total reward = 0.
# Iteration #959401 -- Total reward = 0.
# Iteration #959601 -- Total reward = 0.
# Iteration #959801 -- Total reward = 0.
# Iteration #960001 -- Total reward = 0.
# Iteration #960201 -- Total reward = 1.
# Iteration #960401 -- Total reward = 0.
# Iteration #960601 -- Total reward = 1.
# Iteration #960801 -- Total reward = 0.
# Iteration #961001 -- Total reward = 1.
# Iteration #961201 -- Total reward = 1.
# Iteration #961401 -- Total reward = 0.
# Iteration #961601 -- Total reward = 0.
# Iteration #961801 -- Total reward = 0.
# Iteration #962001 -- Total reward = 1.
# Iteration #962201 -- Total reward = 1.
# Iteration #962401 -- Total reward = 0.
# Iteration #962601 -- Total reward = 1.
# Iteration #962801 -- Total reward = 1.
# Iteration #963001 -- Total reward = 0.
# Iteration #963201 -- Total reward = 0.
# Iteration #963401 -- Total reward = 0.
# Iteration #963601 -- Total reward = 0.
# Iteration #963801 -- Total reward = 1.
# Iteration #964001 -- Total reward = 0.
# Iteration #964201 -- Total reward = 1.
# Iteration #964401 -- Total reward = 0.
# Iteration #964601 -- Total reward = 0.
# Iteration #964801 -- Total reward = 0.
# Iteration #965001 -- Total reward = 1.
# Iteration #965201 -- Total reward = 1.
# Iteration #965401 -- Total reward = 0.
# Iteration #965601 -- Total reward = 1.
# Iteration #965801 -- Total reward = 1.
# Iteration #966001 -- Total reward = 1.
# Iteration #966201 -- Total reward = 1.
# Iteration #966401 -- Total reward = 1.
# Iteration #966601 -- Total reward = 1.
# Iteration #966801 -- Total reward = 1.
# Iteration #967001 -- Total reward = 0.
# Iteration #967201 -- Total reward = 0.
# Iteration #967401 -- Total reward = 0.
# Iteration #967601 -- Total reward = 0.
# Iteration #967801 -- Total reward = 0.
# Iteration #968001 -- Total reward = 1.
# Iteration #968201 -- Total reward = 1.
# Iteration #968401 -- Total reward = 1.
# Iteration #968601 -- Total reward = 1.
# Iteration #968801 -- Total reward = 0.
# Iteration #969001 -- Total reward = 1.
# Iteration #969201 -- Total reward = 0.
# Iteration #969401 -- Total reward = 1.
# Iteration #969601 -- Total reward = 0.
# Iteration #969801 -- Total reward = 0.
# Iteration #970001 -- Total reward = 0.
# Iteration #970201 -- Total reward = 0.
# Iteration #970401 -- Total reward = 1.
# Iteration #970601 -- Total reward = 1.
# Iteration #970801 -- Total reward = 0.
# Iteration #971001 -- Total reward = 1.
# Iteration #971201 -- Total reward = 1.
# Iteration #971401 -- Total reward = 1.
# Iteration #971601 -- Total reward = 0.
# Iteration #971801 -- Total reward = 0.
# Iteration #972001 -- Total reward = 1.
# Iteration #972201 -- Total reward = 1.
# Iteration #972401 -- Total reward = 1.
# Iteration #972601 -- Total reward = 0.
# Iteration #972801 -- Total reward = 1.
# Iteration #973001 -- Total reward = 0.
# Iteration #973201 -- Total reward = 1.
# Iteration #973401 -- Total reward = 1.
# Iteration #973601 -- Total reward = 0.
# Iteration #973801 -- Total reward = 0.
# Iteration #974001 -- Total reward = 0.
# Iteration #974201 -- Total reward = 0.
# Iteration #974401 -- Total reward = 0.
# Iteration #974601 -- Total reward = 0.
# Iteration #974801 -- Total reward = 1.
# Iteration #975001 -- Total reward = 1.
# Iteration #975201 -- Total reward = 1.
# Iteration #975401 -- Total reward = 1.
# Iteration #975601 -- Total reward = 1.
# Iteration #975801 -- Total reward = 1.
# Iteration #976001 -- Total reward = 1.
# Iteration #976201 -- Total reward = 0.
# Iteration #976401 -- Total reward = 1.
# Iteration #976601 -- Total reward = 0.
# Iteration #976801 -- Total reward = 1.
# Iteration #977001 -- Total reward = 1.
# Iteration #977201 -- Total reward = 0.
# Iteration #977401 -- Total reward = 1.
# Iteration #977601 -- Total reward = 0.
# Iteration #977801 -- Total reward = 1.
# Iteration #978001 -- Total reward = 1.
# Iteration #978201 -- Total reward = 0.
# Iteration #978401 -- Total reward = 0.
# Iteration #978601 -- Total reward = 0.
# Iteration #978801 -- Total reward = 0.
# Iteration #979001 -- Total reward = 1.
# Iteration #979201 -- Total reward = 0.
# Iteration #979401 -- Total reward = 1.
# Iteration #979601 -- Total reward = 0.
# Iteration #979801 -- Total reward = 1.
# Iteration #980001 -- Total reward = 0.
# Iteration #980201 -- Total reward = 1.
# Iteration #980401 -- Total reward = 0.
# Iteration #980601 -- Total reward = 1.
# Iteration #980801 -- Total reward = 1.
# Iteration #981001 -- Total reward = 0.
# Iteration #981201 -- Total reward = 1.
# Iteration #981401 -- Total reward = 1.
# Iteration #981601 -- Total reward = 0.
# Iteration #981801 -- Total reward = 0.
# Iteration #982001 -- Total reward = 1.
# Iteration #982201 -- Total reward = 0.
# Iteration #982401 -- Total reward = 0.
# Iteration #982601 -- Total reward = 0.
# Iteration #982801 -- Total reward = 1.
# Iteration #983001 -- Total reward = 1.
# Iteration #983201 -- Total reward = 0.
# Iteration #983401 -- Total reward = 0.
# Iteration #983601 -- Total reward = 1.
# Iteration #983801 -- Total reward = 1.
# Iteration #984001 -- Total reward = 1.
# Iteration #984201 -- Total reward = 1.
# Iteration #984401 -- Total reward = 0.
# Iteration #984601 -- Total reward = 1.
# Iteration #984801 -- Total reward = 0.
# Iteration #985001 -- Total reward = 1.
# Iteration #985201 -- Total reward = 1.
# Iteration #985401 -- Total reward = 1.
# Iteration #985601 -- Total reward = 0.
# Iteration #985801 -- Total reward = 1.
# Iteration #986001 -- Total reward = 0.
# Iteration #986201 -- Total reward = 1.
# Iteration #986401 -- Total reward = 1.
# Iteration #986601 -- Total reward = 1.
# Iteration #986801 -- Total reward = 1.
# Iteration #987001 -- Total reward = 1.
# Iteration #987201 -- Total reward = 1.
# Iteration #987401 -- Total reward = 1.
# Iteration #987601 -- Total reward = 0.
# Iteration #987801 -- Total reward = 1.
# Iteration #988001 -- Total reward = 1.
# Iteration #988201 -- Total reward = 0.
# Iteration #988401 -- Total reward = 0.
# Iteration #988601 -- Total reward = 1.
# Iteration #988801 -- Total reward = 0.
# Iteration #989001 -- Total reward = 0.
# Iteration #989201 -- Total reward = 1.
# Iteration #989401 -- Total reward = 1.
# Iteration #989601 -- Total reward = 1.
# Iteration #989801 -- Total reward = 1.
# Iteration #990001 -- Total reward = 1.
# Iteration #990201 -- Total reward = 0.
# Iteration #990401 -- Total reward = 1.
# Iteration #990601 -- Total reward = 1.
# Iteration #990801 -- Total reward = 0.
# Iteration #991001 -- Total reward = 0.
# Iteration #991201 -- Total reward = 0.
# Iteration #991401 -- Total reward = 1.
# Iteration #991601 -- Total reward = 0.
# Iteration #991801 -- Total reward = 0.
# Iteration #992001 -- Total reward = 1.
# Iteration #992201 -- Total reward = 0.
# Iteration #992401 -- Total reward = 1.
# Iteration #992601 -- Total reward = 0.
# Iteration #992801 -- Total reward = 1.
# Iteration #993001 -- Total reward = 1.
# Iteration #993201 -- Total reward = 0.
# Iteration #993401 -- Total reward = 0.
# Iteration #993601 -- Total reward = 1.
# Iteration #993801 -- Total reward = 0.
# Iteration #994001 -- Total reward = 1.
# Iteration #994201 -- Total reward = 0.
# Iteration #994401 -- Total reward = 0.
# Iteration #994601 -- Total reward = 1.
# Iteration #994801 -- Total reward = 0.
# Iteration #995001 -- Total reward = 1.
# Iteration #995201 -- Total reward = 0.
# Iteration #995401 -- Total reward = 0.
# Iteration #995601 -- Total reward = 1.
# Iteration #995801 -- Total reward = 0.
# Iteration #996001 -- Total reward = 1.
# Iteration #996201 -- Total reward = 0.
# Iteration #996401 -- Total reward = 1.
# Iteration #996601 -- Total reward = 0.
# Iteration #996801 -- Total reward = 0.
# Iteration #997001 -- Total reward = 1.
# Iteration #997201 -- Total reward = 0.
# Iteration #997401 -- Total reward = 1.
# Iteration #997601 -- Total reward = 0.
# Iteration #997801 -- Total reward = 0.
# Iteration #998001 -- Total reward = 1.
# Iteration #998201 -- Total reward = 1.
# Iteration #998401 -- Total reward = 1.
# Iteration #998601 -- Total reward = 1.
# Iteration #998801 -- Total reward = 1.
# Iteration #999001 -- Total reward = 1.
# Iteration #999201 -- Total reward = 0.
# Iteration #999401 -- Total reward = 1.
# Iteration #999601 -- Total reward = 0.
# Iteration #999801 -- Total reward = 0.
# Average score of solution =  0.74
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-80bb98ac9bd4> in <module>
#      91
#      92 # Animate it
# ---> 93 if solution_policy_scores > 0.7:
#      94     for i in range(2):
#      95         print('episode {}'.format(i))
#
# TypeError: '>' not supported between instances of 'list' and 'float'

# %%
np.mean([run_episode(env, solution_policy, False) for _ in range(100)])
# Out:
# 0.71

# %% [markdown]
# ### test

# %%
q_table = np.load('frozenlake-v0_Qtable_Qlearning.npy')

def run_episode(env, policy=None, render=False):
    obs = env.reset()
    total_reward = 0
    steps = 0
    for _ in range(t_max):
        if render:
            env.render()
        '''
        we could also only print the last state (to see if our agent is on the goal or fall into an hole)
        put the 'env.render()' into the 'done:'
        '''
        if policy is None:
            action = env.action_space.sample()
        else:
            action = policy[obs]
        obs, reward, done, _ = env.step(action)
        total_reward += gamma**steps * reward
        steps += 1
        
        if done:
            break
    return total_reward


solution_policy = np.argmax(q_table, axis=1)

print(np.mean([run_episode(env, solution_policy, False) for _ in range(100)]))

run_episode(env, solution_policy, True)

# %% [markdown]
# ## SARSA

# %%
off_policy = False
env.seed(123)
np.random.seed(123)

if off_policy == True:
    print ('----- using Q Learning -----')
else:
    print('------ using SARSA Learning ---')

q_table = np.zeros((env.observation_space.n, env.action_space.n))   # (16, 4)
returns = []
for i in range(iter_max):
    obs = env.reset()
    total_reward = 0
    # eta: learning rate is decayed every 100 steps
    eta = max(min_lr, initial_lr * (0.85**(i//100)))
    
    for j in range(t_max):
        if np.random.uniform(0, 1) < eps:
            action = np.random.choice(env.action_space.n)
        else:
            action = np.argmax(q_table[obs])
        
        obs_tp1, reward, done, _ = env.step(action)
        total_reward += reward
        
        # update q table
        if off_policy == True:
            # q-learning
            target = reward + gamma * np.max(q_table[obs_tp1]) * (1 - done)
            q_table[obs][action] = q_table[obs][action] + eta * (target - q_table[obs][action])
        else:
            # Sarsa
            if np.random.uniform(0, 1) < eps:
                action_ = np.random.choice(env.action_space.n)
            else:
                action_ = np.argmax(q_table[obs_tp1])
            target = reward + gamma * q_table[obs_tp1][action_] * (1 - done)
            q_table[obs][action] = q_table[obs][action] + eta * (target - q_table[obs][action])
        
        obs = obs_tp1
        if done:
            returns.append(total_reward)
            break
        
    if i % 200 == 0:
        print('Iteration #%d -- Total reward = %d.' %(i+1, total_reward))
        
    if np.array(returns[-100:]).mean() > 0.7:
        break
        
        
solution_policy = np.argmax(q_table, axis=1)
solution_policy_scores = [run_episode(env, solution_policy, False) for _ in range(100)]
print("Average score of solution = ", np.mean(solution_policy_scores))

# Animate it
if np.mean(solution_policy_scores) > 0.7:
    for i in range(2):
        print('episode {}'.format(i))
        run_episode(env, solution_policy, True)
env.close()

# %% [markdown]
# # MountainCar-v0
#
# [介绍](https://github.com/openai/gym/wiki/MountainCar-v0)
#
# **MountainCar-v0 defines "solving" as getting average reward of -110.0 over 100 consecutive trials.**

# %%
name = "MountainCar-v0"
env = gym.make(name)

# env.observation_space, env.action_space
# env.observation_space.sample(), env.action_space.sample()
# env.observation_space.high, env.observation_space.low
"""
状态是一个2维连续变量【位置, 速度】, 动作是一个离散变量, 取值 0（向左推）, 1（不动）, 2（向右推）
只有到达右边山顶的黄旗处得0.5, 其他状态都是0
"""

off_policy = True # if True use q-learning, if False use Sarsa

n_states = 40
def obs_to_state(env, obs):
    """
    Map an observation to state
    discrete the continuous observation space
    """
    env_low = env.observation_space.low
    env_high = env.observation_space.high
    env_dx = (env_high - env_low) / n_states
    a = int((obs[0] - env_low[0])/env_dx[0])
    b = int((obs[1] - env_low[1])/env_dx[1])
    return a, b



t_max = 10000
def run_episode(env, policy=None, render=False):
    obs = env.reset()
    total_reward = 0
    steps = 0
    for _ in range(t_max):
        if render:
            env.render()
        if policy is None:
            action = env.action_space.sample()
        else:
            a, b = obs_to_state(env, obs)
            action = policy[a][b]
        obs, reward, done, _ = env.step(action)
        total_reward += gamma**steps * reward
        steps += 1
        
        if done:
            break
    return total_reward



iter_max = int(1e6)
initial_lr = 1.0
min_lr = 0.003
gamma = 1.0
eps = 0.1
env.seed(0)
np.random.seed(0)

if off_policy == True:
    print ('----- using Q Learning -----')
else:
    print('------ using SARSA Learning ---')

q_table = np.zeros((n_states, n_states, 3))

returns = []
for i in range(iter_max):
    obs = env.reset()
    total_reward = 0
    # eta: learning rate is decayed every 100 steps
    eta = max(min_lr, initial_lr * (0.85**(i//100)))
    
    for j in range(t_max):
        a, b = obs_to_state(env, obs)
        if np.random.uniform(0, 1) < eps:
            action = np.random.choice(env.action_space.n)
        else:
            action = np.argmax(q_table[a][b])
        
        obs, reward, done, _ = env.step(action)
        total_reward += reward
        
        # update q table
        a_, b_ = obs_to_state(env, obs)
        if off_policy == True:
            # q-learning
            target = reward + gamma * np.max(q_table[a_][b_]) * (1 - done)
            q_table[a][b][action] = q_table[a][b][action] + eta * (target - q_table[a][b][action])
        else:
            # Sarsa
            if np.random.uniform(0, 1) < eps:
                action_ = np.random.choice(env.action_space.n)
            else:
                action_ = np.argmax(q_table[a_][b_])
            target = reward + gamma * q_table[a_][b_][action_] * (1 - done)
            q_table[a][b][action] = q_table[a][b][action] + eta * (target - q_table[a][b][action])
            
        if done:
            returns.append(total_reward)
            break
        
    if i % 200 == 0:
        print('Iteration #%d -- Total reward = %d.' %(i+1, total_reward))
     
    if np.mean(returns[-100:]) > -110:
        break
    
solution_policy = np.argmax(q_table, axis=2)
solution_policy_scores = [run_episode(env, solution_policy, False) for _ in range(100)]
print("Average score of solution = ", np.mean(solution_policy_scores))

# Animate it
if np.mean(solution_policy_scores) >= -110:
    for _ in range(2):
        run_episode(env, solution_policy, True)
env.close()
# Out:
# ----- using Q Learning -----
# Iteration #1 -- Total reward = -200.
# Iteration #201 -- Total reward = -200.
# Iteration #401 -- Total reward = -200.
# Iteration #601 -- Total reward = -200.
# Iteration #801 -- Total reward = -200.
# Iteration #1001 -- Total reward = -200.
# Iteration #1201 -- Total reward = -200.
# Iteration #1401 -- Total reward = -200.
# Iteration #1601 -- Total reward = -200.
# Iteration #1801 -- Total reward = -200.
# Iteration #2001 -- Total reward = -160.
# Iteration #2201 -- Total reward = -191.
# Iteration #2401 -- Total reward = -156.
# Iteration #2601 -- Total reward = -200.
# Iteration #2801 -- Total reward = -154.
# Iteration #3001 -- Total reward = -151.
# Iteration #3201 -- Total reward = -158.
# Iteration #3401 -- Total reward = -158.
# Iteration #3601 -- Total reward = -157.
# Iteration #3801 -- Total reward = -191.
# Iteration #4001 -- Total reward = -200.
# Iteration #4201 -- Total reward = -200.
# Iteration #4401 -- Total reward = -200.
# Iteration #4601 -- Total reward = -163.
# Iteration #4801 -- Total reward = -200.
# Iteration #5001 -- Total reward = -200.
# Iteration #5201 -- Total reward = -200.
# Iteration #5401 -- Total reward = -161.
# Iteration #5601 -- Total reward = -159.
# Iteration #5801 -- Total reward = -200.
# Iteration #6001 -- Total reward = -200.
# Iteration #6201 -- Total reward = -200.
# Iteration #6401 -- Total reward = -158.
# Iteration #6601 -- Total reward = -200.
# Iteration #6801 -- Total reward = -127.
# Iteration #7001 -- Total reward = -167.
# Iteration #7201 -- Total reward = -200.
# Iteration #7401 -- Total reward = -154.
# Iteration #7601 -- Total reward = -159.
# Iteration #7801 -- Total reward = -165.
# Iteration #8001 -- Total reward = -200.
# Iteration #8201 -- Total reward = -161.
# Iteration #8401 -- Total reward = -162.
# Iteration #8601 -- Total reward = -165.
# Iteration #8801 -- Total reward = -191.
# Iteration #9001 -- Total reward = -160.
# Iteration #9201 -- Total reward = -200.
# Iteration #9401 -- Total reward = -164.
# Iteration #9601 -- Total reward = -167.
# Iteration #9801 -- Total reward = -200.
# Iteration #10001 -- Total reward = -187.
# Iteration #10201 -- Total reward = -196.
# Iteration #10401 -- Total reward = -200.
# Iteration #10601 -- Total reward = -157.
# Iteration #10801 -- Total reward = -155.
# Iteration #11001 -- Total reward = -154.
# Iteration #11201 -- Total reward = -190.
# Iteration #11401 -- Total reward = -161.
# Iteration #11601 -- Total reward = -197.
# Iteration #11801 -- Total reward = -165.
# Iteration #12001 -- Total reward = -158.
# Iteration #12201 -- Total reward = -166.
# Iteration #12401 -- Total reward = -160.
# Iteration #12601 -- Total reward = -155.
# Iteration #12801 -- Total reward = -193.
# Iteration #13001 -- Total reward = -154.
# Iteration #13201 -- Total reward = -200.
# Iteration #13401 -- Total reward = -151.
# Iteration #13601 -- Total reward = -200.
# Iteration #13801 -- Total reward = -166.
# Iteration #14001 -- Total reward = -161.
# Iteration #14201 -- Total reward = -155.
# Iteration #14401 -- Total reward = -155.
# Iteration #14601 -- Total reward = -200.
# Iteration #14801 -- Total reward = -155.
# Iteration #15001 -- Total reward = -153.
# Iteration #15201 -- Total reward = -160.
# Iteration #15401 -- Total reward = -161.
# Iteration #15601 -- Total reward = -166.
# Iteration #15801 -- Total reward = -158.
# Iteration #16001 -- Total reward = -159.
# Iteration #16201 -- Total reward = -147.
# Iteration #16401 -- Total reward = -200.
# Iteration #16601 -- Total reward = -194.
# Iteration #16801 -- Total reward = -156.
# Iteration #17001 -- Total reward = -148.
# Iteration #17201 -- Total reward = -149.
# Iteration #17401 -- Total reward = -149.
# Iteration #17601 -- Total reward = -200.
# Iteration #17801 -- Total reward = -195.
# Iteration #18001 -- Total reward = -149.
# Iteration #18201 -- Total reward = -158.
# Iteration #18401 -- Total reward = -163.
# Iteration #18601 -- Total reward = -158.
# Iteration #18801 -- Total reward = -198.
# Iteration #19001 -- Total reward = -189.
# Iteration #19201 -- Total reward = -189.
# Iteration #19401 -- Total reward = -170.
# Iteration #19601 -- Total reward = -156.
# Iteration #19801 -- Total reward = -152.
# Iteration #20001 -- Total reward = -153.
# Iteration #20201 -- Total reward = -200.
# Iteration #20401 -- Total reward = -160.
# Iteration #20601 -- Total reward = -192.
# Iteration #20801 -- Total reward = -170.
# Iteration #21001 -- Total reward = -193.
# Iteration #21201 -- Total reward = -162.
# Iteration #21401 -- Total reward = -164.
# Iteration #21601 -- Total reward = -200.
# Iteration #21801 -- Total reward = -161.
# Iteration #22001 -- Total reward = -194.
# Iteration #22201 -- Total reward = -200.
# Iteration #22401 -- Total reward = -200.
# Iteration #22601 -- Total reward = -189.
# Iteration #22801 -- Total reward = -193.
# Iteration #23001 -- Total reward = -193.
# Iteration #23201 -- Total reward = -200.
# Iteration #23401 -- Total reward = -191.
# Iteration #23601 -- Total reward = -156.
# Iteration #23801 -- Total reward = -200.
# Iteration #24001 -- Total reward = -162.
# Iteration #24201 -- Total reward = -167.
# Iteration #24401 -- Total reward = -200.
# Iteration #24601 -- Total reward = -196.
# Iteration #24801 -- Total reward = -167.
# Iteration #25001 -- Total reward = -168.
# Iteration #25201 -- Total reward = -161.
# Iteration #25401 -- Total reward = -162.
# Iteration #25601 -- Total reward = -200.
# Iteration #25801 -- Total reward = -195.
# Iteration #26001 -- Total reward = -163.
# Iteration #26201 -- Total reward = -163.
# Iteration #26401 -- Total reward = -159.
# Iteration #26601 -- Total reward = -192.
# Iteration #26801 -- Total reward = -162.
# Iteration #27001 -- Total reward = -168.
# Iteration #27201 -- Total reward = -158.
# Iteration #27401 -- Total reward = -200.
# Iteration #27601 -- Total reward = -157.
# Iteration #27801 -- Total reward = -166.
# Iteration #28001 -- Total reward = -193.
# Iteration #28201 -- Total reward = -196.
# Iteration #28401 -- Total reward = -159.
# Iteration #28601 -- Total reward = -200.
# Iteration #28801 -- Total reward = -123.
# Iteration #29001 -- Total reward = -200.
# Iteration #29201 -- Total reward = -159.
# Iteration #29401 -- Total reward = -200.
# Iteration #29601 -- Total reward = -198.
# Iteration #29801 -- Total reward = -128.
# Iteration #30001 -- Total reward = -200.
# Iteration #30201 -- Total reward = -200.
# Iteration #30401 -- Total reward = -160.
# Iteration #30601 -- Total reward = -192.
# Iteration #30801 -- Total reward = -200.
# Iteration #31001 -- Total reward = -200.
# Iteration #31201 -- Total reward = -200.
# Iteration #31401 -- Total reward = -200.
# Iteration #31601 -- Total reward = -200.
# Iteration #31801 -- Total reward = -165.
# Iteration #32001 -- Total reward = -164.
# Iteration #32201 -- Total reward = -181.
# Iteration #32401 -- Total reward = -192.
# Iteration #32601 -- Total reward = -188.
# Iteration #32801 -- Total reward = -200.
# Iteration #33001 -- Total reward = -155.
# Iteration #33201 -- Total reward = -188.
# Iteration #33401 -- Total reward = -159.
# Iteration #33601 -- Total reward = -162.
# Iteration #33801 -- Total reward = -200.
# Iteration #34001 -- Total reward = -168.
# Iteration #34201 -- Total reward = -157.
# Iteration #34401 -- Total reward = -163.
# Iteration #34601 -- Total reward = -170.
# Iteration #34801 -- Total reward = -196.
# Iteration #35001 -- Total reward = -155.
# Iteration #35201 -- Total reward = -200.
# Iteration #35401 -- Total reward = -197.
# Iteration #35601 -- Total reward = -200.
# Iteration #35801 -- Total reward = -200.
# Iteration #36001 -- Total reward = -200.
# Iteration #36201 -- Total reward = -200.
# Iteration #36401 -- Total reward = -200.
# Iteration #36601 -- Total reward = -200.
# Iteration #36801 -- Total reward = -200.
# Iteration #37001 -- Total reward = -200.
# Iteration #37201 -- Total reward = -200.
# Iteration #37401 -- Total reward = -200.
# Iteration #37601 -- Total reward = -157.
# Iteration #37801 -- Total reward = -200.
# Iteration #38001 -- Total reward = -200.
# Iteration #38201 -- Total reward = -200.
# Iteration #38401 -- Total reward = -197.
# Iteration #38601 -- Total reward = -200.
# Iteration #38801 -- Total reward = -193.
# Iteration #39001 -- Total reward = -152.
# Iteration #39201 -- Total reward = -200.
# Iteration #39401 -- Total reward = -200.
# Iteration #39601 -- Total reward = -200.
# Iteration #39801 -- Total reward = -200.
# Iteration #40001 -- Total reward = -200.
# Iteration #40201 -- Total reward = -200.
# Iteration #40401 -- Total reward = -151.
# Iteration #40601 -- Total reward = -200.
# Iteration #40801 -- Total reward = -153.
# Iteration #41001 -- Total reward = -200.
# Iteration #41201 -- Total reward = -200.
# Iteration #41401 -- Total reward = -198.
# Iteration #41601 -- Total reward = -200.
# Iteration #41801 -- Total reward = -193.
# Iteration #42001 -- Total reward = -200.
# Iteration #42201 -- Total reward = -191.
# Iteration #42401 -- Total reward = -200.
# Iteration #42601 -- Total reward = -200.
# Iteration #42801 -- Total reward = -186.
# Iteration #43001 -- Total reward = -193.
# Iteration #43201 -- Total reward = -196.
# Iteration #43401 -- Total reward = -200.
# Iteration #43601 -- Total reward = -200.
# Iteration #43801 -- Total reward = -200.
# Iteration #44001 -- Total reward = -200.
# Iteration #44201 -- Total reward = -200.
# Iteration #44401 -- Total reward = -200.
# Iteration #44601 -- Total reward = -190.
# Iteration #44801 -- Total reward = -200.
# Iteration #45001 -- Total reward = -169.
# Iteration #45201 -- Total reward = -196.
# Iteration #45401 -- Total reward = -198.
# Iteration #45601 -- Total reward = -187.
# Iteration #45801 -- Total reward = -200.
# Iteration #46001 -- Total reward = -196.
# Iteration #46201 -- Total reward = -200.
# Iteration #46401 -- Total reward = -169.
# Iteration #46601 -- Total reward = -163.
# Iteration #46801 -- Total reward = -193.
# Iteration #47001 -- Total reward = -200.
# Iteration #47201 -- Total reward = -154.
# Iteration #47401 -- Total reward = -200.
# Iteration #47601 -- Total reward = -200.
# Iteration #47801 -- Total reward = -160.
# Iteration #48001 -- Total reward = -200.
# Iteration #48201 -- Total reward = -155.
# Iteration #48401 -- Total reward = -171.
# Iteration #48601 -- Total reward = -200.
# Iteration #48801 -- Total reward = -156.
# Iteration #49001 -- Total reward = -196.
# Iteration #49201 -- Total reward = -156.
# Iteration #49401 -- Total reward = -157.
# Iteration #49601 -- Total reward = -197.
# Iteration #49801 -- Total reward = -199.
# Iteration #50001 -- Total reward = -160.
# Iteration #50201 -- Total reward = -197.
# Iteration #50401 -- Total reward = -198.
# Iteration #50601 -- Total reward = -200.
# Iteration #50801 -- Total reward = -192.
# Iteration #51001 -- Total reward = -198.
# Iteration #51201 -- Total reward = -200.
# Iteration #51401 -- Total reward = -197.
# Iteration #51601 -- Total reward = -196.
# Iteration #51801 -- Total reward = -161.
# Iteration #52001 -- Total reward = -192.
# Iteration #52201 -- Total reward = -162.
# Iteration #52401 -- Total reward = -158.
# Iteration #52601 -- Total reward = -197.
# Iteration #52801 -- Total reward = -193.
# Iteration #53001 -- Total reward = -199.
# Iteration #53201 -- Total reward = -200.
# Iteration #53401 -- Total reward = -198.
# Iteration #53601 -- Total reward = -200.
# Iteration #53801 -- Total reward = -194.
# Iteration #54001 -- Total reward = -200.
# Iteration #54201 -- Total reward = -194.
# Iteration #54401 -- Total reward = -193.
# Iteration #54601 -- Total reward = -160.
# Iteration #54801 -- Total reward = -158.
# Iteration #55001 -- Total reward = -196.
# Iteration #55201 -- Total reward = -163.
# Iteration #55401 -- Total reward = -164.
# Iteration #55601 -- Total reward = -193.
# Iteration #55801 -- Total reward = -170.
# Iteration #56001 -- Total reward = -158.
# Iteration #56201 -- Total reward = -169.
# Iteration #56401 -- Total reward = -200.
# Iteration #56601 -- Total reward = -200.
# Iteration #56801 -- Total reward = -161.
# Iteration #57001 -- Total reward = -195.
# Iteration #57201 -- Total reward = -166.
# Iteration #57401 -- Total reward = -165.
# Iteration #57601 -- Total reward = -172.
# Iteration #57801 -- Total reward = -166.
# Iteration #58001 -- Total reward = -200.
# Iteration #58201 -- Total reward = -165.
# Iteration #58401 -- Total reward = -194.
# Iteration #58601 -- Total reward = -162.
# Iteration #58801 -- Total reward = -160.
# Iteration #59001 -- Total reward = -170.
# Iteration #59201 -- Total reward = -179.
# Iteration #59401 -- Total reward = -166.
# Iteration #59601 -- Total reward = -198.
# Iteration #59801 -- Total reward = -200.
# Iteration #60001 -- Total reward = -152.
# Iteration #60201 -- Total reward = -191.
# Iteration #60401 -- Total reward = -198.
# Iteration #60601 -- Total reward = -175.
# Iteration #60801 -- Total reward = -200.
# Iteration #61001 -- Total reward = -188.
# Iteration #61201 -- Total reward = -162.
# Iteration #61401 -- Total reward = -163.
# Iteration #61601 -- Total reward = -163.
# Iteration #61801 -- Total reward = -168.
# Iteration #62001 -- Total reward = -159.
# Iteration #62201 -- Total reward = -166.
# Iteration #62401 -- Total reward = -153.
# Iteration #62601 -- Total reward = -135.
# Iteration #62801 -- Total reward = -140.
# Iteration #63001 -- Total reward = -157.
# Iteration #63201 -- Total reward = -174.
# Iteration #63401 -- Total reward = -173.
# Iteration #63601 -- Total reward = -165.
# Iteration #63801 -- Total reward = -157.
# Iteration #64001 -- Total reward = -157.
# Iteration #64201 -- Total reward = -200.
# Iteration #64401 -- Total reward = -200.
# Iteration #64601 -- Total reward = -200.
# Iteration #64801 -- Total reward = -200.
# Iteration #65001 -- Total reward = -200.
# Iteration #65201 -- Total reward = -156.
# Iteration #65401 -- Total reward = -200.
# Iteration #65601 -- Total reward = -134.
# Iteration #65801 -- Total reward = -131.
# Iteration #66001 -- Total reward = -200.
# Iteration #66201 -- Total reward = -200.
# Iteration #66401 -- Total reward = -161.
# Iteration #66601 -- Total reward = -200.
# Iteration #66801 -- Total reward = -200.
# Iteration #67001 -- Total reward = -200.
# Iteration #67201 -- Total reward = -147.
# Iteration #67401 -- Total reward = -167.
# Iteration #67601 -- Total reward = -153.
# Iteration #67801 -- Total reward = -200.
# Iteration #68001 -- Total reward = -200.
# Iteration #68201 -- Total reward = -200.
# Iteration #68401 -- Total reward = -200.
# Iteration #68601 -- Total reward = -200.
# Iteration #68801 -- Total reward = -200.
# Iteration #69001 -- Total reward = -200.
# Iteration #69201 -- Total reward = -200.
# Iteration #69401 -- Total reward = -200.
# Iteration #69601 -- Total reward = -200.
# Iteration #69801 -- Total reward = -200.
# Iteration #70001 -- Total reward = -200.
# Iteration #70201 -- Total reward = -153.
# Iteration #70401 -- Total reward = -195.
# Iteration #70601 -- Total reward = -196.
# Iteration #70801 -- Total reward = -200.
# Iteration #71001 -- Total reward = -200.
# Iteration #71201 -- Total reward = -197.
# Iteration #71401 -- Total reward = -196.
# Iteration #71601 -- Total reward = -194.
# Iteration #71801 -- Total reward = -160.
# Iteration #72001 -- Total reward = -191.
# Iteration #72201 -- Total reward = -162.
# Iteration #72401 -- Total reward = -200.
# Iteration #72601 -- Total reward = -193.
# Iteration #72801 -- Total reward = -170.
# Iteration #73001 -- Total reward = -200.
# Iteration #73201 -- Total reward = -155.
# Iteration #73401 -- Total reward = -136.
# Iteration #73601 -- Total reward = -164.
# Iteration #73801 -- Total reward = -150.
# Iteration #74001 -- Total reward = -196.
# Iteration #74201 -- Total reward = -162.
# Iteration #74401 -- Total reward = -153.
# Iteration #74601 -- Total reward = -161.
# Iteration #74801 -- Total reward = -159.
# Iteration #75001 -- Total reward = -200.
# Iteration #75201 -- Total reward = -200.
# Iteration #75401 -- Total reward = -161.
# Iteration #75601 -- Total reward = -196.
# Iteration #75801 -- Total reward = -162.
# Iteration #76001 -- Total reward = -157.
# Iteration #76201 -- Total reward = -199.
# Iteration #76401 -- Total reward = -161.
# Iteration #76601 -- Total reward = -160.
# Iteration #76801 -- Total reward = -200.
# Iteration #77001 -- Total reward = -161.
# Iteration #77201 -- Total reward = -154.
# Iteration #77401 -- Total reward = -200.
# Iteration #77601 -- Total reward = -200.
# Iteration #77801 -- Total reward = -200.
# Iteration #78001 -- Total reward = -155.
# Iteration #78201 -- Total reward = -199.
# Iteration #78401 -- Total reward = -150.
# Iteration #78601 -- Total reward = -194.
# Iteration #78801 -- Total reward = -156.
# Iteration #79001 -- Total reward = -152.
# Iteration #79201 -- Total reward = -154.
# Iteration #79401 -- Total reward = -152.
# Iteration #79601 -- Total reward = -152.
# Iteration #79801 -- Total reward = -155.
# Iteration #80001 -- Total reward = -160.
# Iteration #80201 -- Total reward = -199.
# Iteration #80401 -- Total reward = -158.
# Iteration #80601 -- Total reward = -192.
# Iteration #80801 -- Total reward = -152.
# Iteration #81001 -- Total reward = -161.
# Iteration #81201 -- Total reward = -155.
# Iteration #81401 -- Total reward = -155.
# Iteration #81601 -- Total reward = -157.
# Iteration #81801 -- Total reward = -196.
# Iteration #82001 -- Total reward = -158.
# Iteration #82201 -- Total reward = -165.
# Iteration #82401 -- Total reward = -197.
# Iteration #82601 -- Total reward = -158.
# Iteration #82801 -- Total reward = -191.
# Iteration #83001 -- Total reward = -153.
# Iteration #83201 -- Total reward = -158.
# Iteration #83401 -- Total reward = -158.
# Iteration #83601 -- Total reward = -154.
# Iteration #83801 -- Total reward = -192.
# Iteration #84001 -- Total reward = -162.
# Iteration #84201 -- Total reward = -200.
# Iteration #84401 -- Total reward = -162.
# Iteration #84601 -- Total reward = -196.
# Iteration #84801 -- Total reward = -155.
# Iteration #85001 -- Total reward = -157.
# Iteration #85201 -- Total reward = -168.
# Iteration #85401 -- Total reward = -152.
# Iteration #85601 -- Total reward = -163.
# Iteration #85801 -- Total reward = -150.
# Iteration #86001 -- Total reward = -154.
# Iteration #86201 -- Total reward = -161.
# Iteration #86401 -- Total reward = -193.
# Iteration #86601 -- Total reward = -153.
# Iteration #86801 -- Total reward = -160.
# Iteration #87001 -- Total reward = -157.
# Iteration #87201 -- Total reward = -149.
# Iteration #87401 -- Total reward = -151.
# Iteration #87601 -- Total reward = -200.
# Iteration #87801 -- Total reward = -200.
# Iteration #88001 -- Total reward = -200.
# Iteration #88201 -- Total reward = -114.
# Iteration #88401 -- Total reward = -190.
# Iteration #88601 -- Total reward = -163.
# Iteration #88801 -- Total reward = -200.
# Iteration #89001 -- Total reward = -148.
# Iteration #89201 -- Total reward = -200.
# Iteration #89401 -- Total reward = -163.
# Iteration #89601 -- Total reward = -165.
# Iteration #89801 -- Total reward = -200.
# Iteration #90001 -- Total reward = -193.
# Iteration #90201 -- Total reward = -152.
# Iteration #90401 -- Total reward = -166.
# Iteration #90601 -- Total reward = -156.
# Iteration #90801 -- Total reward = -154.
# Iteration #91001 -- Total reward = -200.
# Iteration #91201 -- Total reward = -200.
# Iteration #91401 -- Total reward = -167.
# Iteration #91601 -- Total reward = -125.
# Iteration #91801 -- Total reward = -167.
# Iteration #92001 -- Total reward = -143.
# Iteration #92201 -- Total reward = -161.
# Iteration #92401 -- Total reward = -160.
# Iteration #92601 -- Total reward = -124.
# Iteration #92801 -- Total reward = -157.
# Iteration #93001 -- Total reward = -166.
# Iteration #93201 -- Total reward = -162.
# Iteration #93401 -- Total reward = -126.
# Iteration #93601 -- Total reward = -159.
# Iteration #93801 -- Total reward = -160.
# Iteration #94001 -- Total reward = -157.
# Iteration #94201 -- Total reward = -125.
# Iteration #94401 -- Total reward = -113.
# Iteration #94601 -- Total reward = -157.
# Iteration #94801 -- Total reward = -154.
# Iteration #95001 -- Total reward = -126.
# Iteration #95201 -- Total reward = -157.
# Iteration #95401 -- Total reward = -155.
# Iteration #95601 -- Total reward = -200.
# Iteration #95801 -- Total reward = -124.
# Iteration #96001 -- Total reward = -156.
# Iteration #96201 -- Total reward = -198.
# Iteration #96401 -- Total reward = -172.
# Iteration #96601 -- Total reward = -161.
# Iteration #96801 -- Total reward = -122.
# Iteration #97001 -- Total reward = -200.
# Iteration #97201 -- Total reward = -200.
# Iteration #97401 -- Total reward = -200.
# Iteration #97601 -- Total reward = -158.
# Iteration #97801 -- Total reward = -154.
# Iteration #98001 -- Total reward = -200.
# Iteration #98201 -- Total reward = -123.
# Iteration #98401 -- Total reward = -200.
# Iteration #98601 -- Total reward = -166.
# Iteration #98801 -- Total reward = -197.
# Iteration #99001 -- Total reward = -157.
# Iteration #99201 -- Total reward = -169.
# Iteration #99401 -- Total reward = -167.
# Iteration #99601 -- Total reward = -200.
# Iteration #99801 -- Total reward = -167.
# Iteration #100001 -- Total reward = -195.
# Iteration #100201 -- Total reward = -168.
# Iteration #100401 -- Total reward = -150.
# Iteration #100601 -- Total reward = -156.
# Iteration #100801 -- Total reward = -154.
# Iteration #101001 -- Total reward = -129.
# Iteration #101201 -- Total reward = -121.
# Iteration #101401 -- Total reward = -200.
# Iteration #101601 -- Total reward = -157.
# Iteration #101801 -- Total reward = -155.
# Iteration #102001 -- Total reward = -157.
# Iteration #102201 -- Total reward = -160.
# Iteration #102401 -- Total reward = -157.
# Iteration #102601 -- Total reward = -156.
# Iteration #102801 -- Total reward = -127.
# Iteration #103001 -- Total reward = -157.
# Iteration #103201 -- Total reward = -118.
# Iteration #103401 -- Total reward = -126.
# Iteration #103601 -- Total reward = -160.
# Iteration #103801 -- Total reward = -122.
# Iteration #104001 -- Total reward = -154.
# Iteration #104201 -- Total reward = -124.
# Iteration #104401 -- Total reward = -159.
# Iteration #104601 -- Total reward = -155.
# Iteration #104801 -- Total reward = -163.
# Iteration #105001 -- Total reward = -183.
# Iteration #105201 -- Total reward = -157.
# Iteration #105401 -- Total reward = -123.
# Iteration #105601 -- Total reward = -130.
# Iteration #105801 -- Total reward = -127.
# Iteration #106001 -- Total reward = -121.
# Iteration #106201 -- Total reward = -193.
# Iteration #106401 -- Total reward = -161.
# Iteration #106601 -- Total reward = -128.
# Iteration #106801 -- Total reward = -155.
# Iteration #107001 -- Total reward = -199.
# Iteration #107201 -- Total reward = -155.
# Iteration #107401 -- Total reward = -156.
# Iteration #107601 -- Total reward = -200.
# Iteration #107801 -- Total reward = -149.
# Iteration #108001 -- Total reward = -164.
# Iteration #108201 -- Total reward = -200.
# Iteration #108401 -- Total reward = -160.
# Iteration #108601 -- Total reward = -158.
# Iteration #108801 -- Total reward = -156.
# Iteration #109001 -- Total reward = -129.
# Iteration #109201 -- Total reward = -192.
# Iteration #109401 -- Total reward = -157.
# Iteration #109601 -- Total reward = -164.
# Iteration #109801 -- Total reward = -99.
# Iteration #110001 -- Total reward = -189.
# Iteration #110201 -- Total reward = -164.
# Iteration #110401 -- Total reward = -152.
# Iteration #110601 -- Total reward = -177.
# Iteration #110801 -- Total reward = -163.
# Iteration #111001 -- Total reward = -176.
# Iteration #111201 -- Total reward = -153.
# Iteration #111401 -- Total reward = -200.
# Iteration #111601 -- Total reward = -185.
# Iteration #111801 -- Total reward = -161.
# Iteration #112001 -- Total reward = -157.
# Iteration #112201 -- Total reward = -149.
# Iteration #112401 -- Total reward = -159.
# Iteration #112601 -- Total reward = -153.
# Iteration #112801 -- Total reward = -199.
# Iteration #113001 -- Total reward = -150.
# Iteration #113201 -- Total reward = -161.
# Iteration #113401 -- Total reward = -153.
# Iteration #113601 -- Total reward = -157.
# Iteration #113801 -- Total reward = -157.
# Iteration #114001 -- Total reward = -140.
# Iteration #114201 -- Total reward = -162.
# Iteration #114401 -- Total reward = -151.
# Iteration #114601 -- Total reward = -154.
# Iteration #114801 -- Total reward = -125.
# Iteration #115001 -- Total reward = -151.
# Iteration #115201 -- Total reward = -149.
# Iteration #115401 -- Total reward = -151.
# Iteration #115601 -- Total reward = -156.
# Iteration #115801 -- Total reward = -154.
# Iteration #116001 -- Total reward = -120.
# Iteration #116201 -- Total reward = -160.
# Iteration #116401 -- Total reward = -158.
# Iteration #116601 -- Total reward = -152.
# Iteration #116801 -- Total reward = -146.
# Iteration #117001 -- Total reward = -118.
# Iteration #117201 -- Total reward = -121.
# Iteration #117401 -- Total reward = -159.
# Iteration #117601 -- Total reward = -158.
# Iteration #117801 -- Total reward = -115.
# Iteration #118001 -- Total reward = -159.
# Iteration #118201 -- Total reward = -155.
# Iteration #118401 -- Total reward = -155.
# Iteration #118601 -- Total reward = -155.
# Iteration #118801 -- Total reward = -114.
# Iteration #119001 -- Total reward = -152.
# Iteration #119201 -- Total reward = -120.
# Iteration #119401 -- Total reward = -155.
# Iteration #119601 -- Total reward = -122.
# Iteration #119801 -- Total reward = -116.
# Iteration #120001 -- Total reward = -118.
# Iteration #120201 -- Total reward = -149.
# Iteration #120401 -- Total reward = -155.
# Iteration #120601 -- Total reward = -125.
# Iteration #120801 -- Total reward = -186.
# Iteration #121001 -- Total reward = -157.
# Iteration #121201 -- Total reward = -198.
# Iteration #121401 -- Total reward = -158.
# Iteration #121601 -- Total reward = -193.
# Iteration #121801 -- Total reward = -159.
# Iteration #122001 -- Total reward = -150.
# Iteration #122201 -- Total reward = -119.
# Iteration #122401 -- Total reward = -161.
# Iteration #122601 -- Total reward = -132.
# Iteration #122801 -- Total reward = -162.
# Iteration #123001 -- Total reward = -154.
# Iteration #123201 -- Total reward = -156.
# Iteration #123401 -- Total reward = -197.
# Iteration #123601 -- Total reward = -184.
# Iteration #123801 -- Total reward = -164.
# Iteration #124001 -- Total reward = -183.
# Iteration #124201 -- Total reward = -179.
# Iteration #124401 -- Total reward = -184.
# Iteration #124601 -- Total reward = -156.
# Iteration #124801 -- Total reward = -156.
# Iteration #125001 -- Total reward = -179.
# Iteration #125201 -- Total reward = -186.
# Iteration #125401 -- Total reward = -134.
# Iteration #125601 -- Total reward = -142.
# Iteration #125801 -- Total reward = -153.
# Iteration #126001 -- Total reward = -123.
# Iteration #126201 -- Total reward = -120.
# Iteration #126401 -- Total reward = -149.
# Iteration #126601 -- Total reward = -151.
# Iteration #126801 -- Total reward = -158.
# Iteration #127001 -- Total reward = -121.
# Iteration #127201 -- Total reward = -128.
# Iteration #127401 -- Total reward = -181.
# Iteration #127601 -- Total reward = -182.
# Iteration #127801 -- Total reward = -118.
# Iteration #128001 -- Total reward = -124.
# Iteration #128201 -- Total reward = -191.
# Iteration #128401 -- Total reward = -157.
# Iteration #128601 -- Total reward = -144.
# Iteration #128801 -- Total reward = -153.
# Iteration #129001 -- Total reward = -118.
# Iteration #129201 -- Total reward = -119.
# Iteration #129401 -- Total reward = -152.
# Iteration #129601 -- Total reward = -151.
# Iteration #129801 -- Total reward = -154.
# Iteration #130001 -- Total reward = -177.
# Iteration #130201 -- Total reward = -191.
# Iteration #130401 -- Total reward = -128.
# Iteration #130601 -- Total reward = -168.
# Iteration #130801 -- Total reward = -200.
# Iteration #131001 -- Total reward = -159.
# Iteration #131201 -- Total reward = -154.
# Iteration #131401 -- Total reward = -154.
# Iteration #131601 -- Total reward = -126.
# Iteration #131801 -- Total reward = -150.
# Iteration #132001 -- Total reward = -127.
# Iteration #132201 -- Total reward = -147.
# Iteration #132401 -- Total reward = -123.
# Iteration #132601 -- Total reward = -200.
# Iteration #132801 -- Total reward = -146.
# Iteration #133001 -- Total reward = -153.
# Iteration #133201 -- Total reward = -126.
# Iteration #133401 -- Total reward = -189.
# Iteration #133601 -- Total reward = -155.
# Iteration #133801 -- Total reward = -187.
# Iteration #134001 -- Total reward = -152.
# Iteration #134201 -- Total reward = -155.
# Iteration #134401 -- Total reward = -157.
# Iteration #134601 -- Total reward = -159.
# Iteration #134801 -- Total reward = -154.
# Iteration #135001 -- Total reward = -147.
# Iteration #135201 -- Total reward = -143.
# Iteration #135401 -- Total reward = -158.
# Iteration #135601 -- Total reward = -157.
# Iteration #135801 -- Total reward = -200.
# Iteration #136001 -- Total reward = -156.
# Iteration #136201 -- Total reward = -160.
# Iteration #136401 -- Total reward = -157.
# Iteration #136601 -- Total reward = -200.
# Iteration #136801 -- Total reward = -192.
# Iteration #137001 -- Total reward = -190.
# Iteration #137201 -- Total reward = -161.
# Iteration #137401 -- Total reward = -191.
# Iteration #137601 -- Total reward = -153.
# Iteration #137801 -- Total reward = -153.
# Iteration #138001 -- Total reward = -198.
# Iteration #138201 -- Total reward = -156.
# Iteration #138401 -- Total reward = -152.
# Iteration #138601 -- Total reward = -133.
# Iteration #138801 -- Total reward = -149.
# Iteration #139001 -- Total reward = -154.
# Iteration #139201 -- Total reward = -152.
# Iteration #139401 -- Total reward = -152.
# Iteration #139601 -- Total reward = -119.
# Iteration #139801 -- Total reward = -123.
# Iteration #140001 -- Total reward = -121.
# Iteration #140201 -- Total reward = -122.
# Iteration #140401 -- Total reward = -152.
# Iteration #140601 -- Total reward = -120.
# Iteration #140801 -- Total reward = -121.
# Iteration #141001 -- Total reward = -121.
# Iteration #141201 -- Total reward = -113.
# Iteration #141401 -- Total reward = -123.
# Iteration #141601 -- Total reward = -122.
# Iteration #141801 -- Total reward = -115.
# Iteration #142001 -- Total reward = -145.
# Iteration #142201 -- Total reward = -125.
# Iteration #142401 -- Total reward = -153.
# Iteration #142601 -- Total reward = -125.
# Iteration #142801 -- Total reward = -126.
# Iteration #143001 -- Total reward = -148.
# Iteration #143201 -- Total reward = -147.
# Iteration #143401 -- Total reward = -151.
# Iteration #143601 -- Total reward = -154.
# Iteration #143801 -- Total reward = -140.
# Iteration #144001 -- Total reward = -146.
# Iteration #144201 -- Total reward = -153.
# Iteration #144401 -- Total reward = -152.
# Iteration #144601 -- Total reward = -147.
# Iteration #144801 -- Total reward = -165.
# Iteration #145001 -- Total reward = -152.
# Iteration #145201 -- Total reward = -149.
# Iteration #145401 -- Total reward = -156.
# Iteration #145601 -- Total reward = -147.
# Iteration #145801 -- Total reward = -157.
# Iteration #146001 -- Total reward = -153.
# Iteration #146201 -- Total reward = -154.
# Iteration #146401 -- Total reward = -127.
# Iteration #146601 -- Total reward = -151.
# Iteration #146801 -- Total reward = -153.
# Iteration #147001 -- Total reward = -122.
# Iteration #147201 -- Total reward = -118.
# Iteration #147401 -- Total reward = -122.
# Iteration #147601 -- Total reward = -147.
# Iteration #147801 -- Total reward = -149.
# Iteration #148001 -- Total reward = -157.
# Iteration #148201 -- Total reward = -109.
# Iteration #148401 -- Total reward = -119.
# Iteration #148601 -- Total reward = -153.
# Iteration #148801 -- Total reward = -178.
# Iteration #149001 -- Total reward = -158.
# Iteration #149201 -- Total reward = -121.
# Iteration #149401 -- Total reward = -121.
# Iteration #149601 -- Total reward = -153.
# Iteration #149801 -- Total reward = -122.
# Iteration #150001 -- Total reward = -122.
# Iteration #150201 -- Total reward = -123.
# Iteration #150401 -- Total reward = -121.
# Iteration #150601 -- Total reward = -151.
# Iteration #150801 -- Total reward = -155.
# Iteration #151001 -- Total reward = -156.
# Iteration #151201 -- Total reward = -124.
# Iteration #151401 -- Total reward = -175.
# Iteration #151601 -- Total reward = -155.
# Iteration #151801 -- Total reward = -153.
# Iteration #152001 -- Total reward = -149.
# Iteration #152201 -- Total reward = -155.
# Iteration #152401 -- Total reward = -122.
# Iteration #152601 -- Total reward = -129.
# Iteration #152801 -- Total reward = -159.
# Iteration #153001 -- Total reward = -153.
# Iteration #153201 -- Total reward = -128.
# Iteration #153401 -- Total reward = -200.
# Iteration #153601 -- Total reward = -145.
# Iteration #153801 -- Total reward = -155.
# Iteration #154001 -- Total reward = -127.
# Iteration #154201 -- Total reward = -123.
# Iteration #154401 -- Total reward = -118.
# Iteration #154601 -- Total reward = -153.
# Iteration #154801 -- Total reward = -151.
# Iteration #155001 -- Total reward = -155.
# Iteration #155201 -- Total reward = -151.
# Iteration #155401 -- Total reward = -159.
# Iteration #155601 -- Total reward = -126.
# Iteration #155801 -- Total reward = -117.
# Iteration #156001 -- Total reward = -159.
# Iteration #156201 -- Total reward = -128.
# Iteration #156401 -- Total reward = -122.
# Iteration #156601 -- Total reward = -125.
# Iteration #156801 -- Total reward = -130.
# Iteration #157001 -- Total reward = -159.
# Iteration #157201 -- Total reward = -131.
# Iteration #157401 -- Total reward = -155.
# Iteration #157601 -- Total reward = -200.
# Iteration #157801 -- Total reward = -126.
# Iteration #158001 -- Total reward = -152.
# Iteration #158201 -- Total reward = -130.
# Iteration #158401 -- Total reward = -167.
# Iteration #158601 -- Total reward = -129.
# Iteration #158801 -- Total reward = -123.
# Iteration #159001 -- Total reward = -118.
# Iteration #159201 -- Total reward = -120.
# Iteration #159401 -- Total reward = -200.
# Iteration #159601 -- Total reward = -156.
# Iteration #159801 -- Total reward = -189.
# Iteration #160001 -- Total reward = -156.
# Iteration #160201 -- Total reward = -122.
# Iteration #160401 -- Total reward = -155.
# Iteration #160601 -- Total reward = -192.
# Iteration #160801 -- Total reward = -139.
# Iteration #161001 -- Total reward = -121.
# Iteration #161201 -- Total reward = -154.
# Iteration #161401 -- Total reward = -115.
# Iteration #161601 -- Total reward = -118.
# Iteration #161801 -- Total reward = -113.
# Iteration #162001 -- Total reward = -164.
# Iteration #162201 -- Total reward = -154.
# Iteration #162401 -- Total reward = -157.
# Iteration #162601 -- Total reward = -170.
# Iteration #162801 -- Total reward = -150.
# Iteration #163001 -- Total reward = -158.
# Iteration #163201 -- Total reward = -158.
# Iteration #163401 -- Total reward = -154.
# Iteration #163601 -- Total reward = -159.
# Iteration #163801 -- Total reward = -153.
# Iteration #164001 -- Total reward = -155.
# Iteration #164201 -- Total reward = -115.
# Iteration #164401 -- Total reward = -154.
# Iteration #164601 -- Total reward = -155.
# Iteration #164801 -- Total reward = -121.
# Iteration #165001 -- Total reward = -146.
# Iteration #165201 -- Total reward = -156.
# Iteration #165401 -- Total reward = -155.
# Iteration #165601 -- Total reward = -200.
# Iteration #165801 -- Total reward = -158.
# Iteration #166001 -- Total reward = -126.
# Iteration #166201 -- Total reward = -138.
# Iteration #166401 -- Total reward = -156.
# Iteration #166601 -- Total reward = -160.
# Iteration #166801 -- Total reward = -155.
# Iteration #167001 -- Total reward = -157.
# Iteration #167201 -- Total reward = -151.
# Iteration #167401 -- Total reward = -156.
# Iteration #167601 -- Total reward = -143.
# Iteration #167801 -- Total reward = -141.
# Iteration #168001 -- Total reward = -153.
# Iteration #168201 -- Total reward = -160.
# Iteration #168401 -- Total reward = -148.
# Iteration #168601 -- Total reward = -146.
# Iteration #168801 -- Total reward = -124.
# Iteration #169001 -- Total reward = -152.
# Iteration #169201 -- Total reward = -134.
# Iteration #169401 -- Total reward = -148.
# Iteration #169601 -- Total reward = -146.
# Iteration #169801 -- Total reward = -153.
# Iteration #170001 -- Total reward = -156.
# Iteration #170201 -- Total reward = -171.
# Iteration #170401 -- Total reward = -154.
# Iteration #170601 -- Total reward = -155.
# Iteration #170801 -- Total reward = -155.
# Iteration #171001 -- Total reward = -189.
# Iteration #171201 -- Total reward = -120.
# Iteration #171401 -- Total reward = -169.
# Iteration #171601 -- Total reward = -158.
# Iteration #171801 -- Total reward = -159.
# Iteration #172001 -- Total reward = -123.
# Iteration #172201 -- Total reward = -156.
# Iteration #172401 -- Total reward = -158.
# Iteration #172601 -- Total reward = -128.
# Iteration #172801 -- Total reward = -157.
# Iteration #173001 -- Total reward = -162.
# Iteration #173201 -- Total reward = -112.
# Iteration #173401 -- Total reward = -159.
# Iteration #173601 -- Total reward = -160.
# Iteration #173801 -- Total reward = -125.
# Iteration #174001 -- Total reward = -147.
# Iteration #174201 -- Total reward = -129.
# Iteration #174401 -- Total reward = -198.
# Iteration #174601 -- Total reward = -160.
# Iteration #174801 -- Total reward = -162.
# Iteration #175001 -- Total reward = -200.
# Iteration #175201 -- Total reward = -125.
# Iteration #175401 -- Total reward = -128.
# Iteration #175601 -- Total reward = -150.
# Iteration #175801 -- Total reward = -164.
# Iteration #176001 -- Total reward = -153.
# Iteration #176201 -- Total reward = -153.
# Iteration #176401 -- Total reward = -159.
# Iteration #176601 -- Total reward = -154.
# Iteration #176801 -- Total reward = -158.
# Iteration #177001 -- Total reward = -193.
# Iteration #177201 -- Total reward = -153.
# Iteration #177401 -- Total reward = -155.
# Iteration #177601 -- Total reward = -189.
# Iteration #177801 -- Total reward = -159.
# Iteration #178001 -- Total reward = -193.
# Iteration #178201 -- Total reward = -144.
# Iteration #178401 -- Total reward = -147.
# Iteration #178601 -- Total reward = -195.
# Iteration #178801 -- Total reward = -188.
# Iteration #179001 -- Total reward = -150.
# Iteration #179201 -- Total reward = -184.
# Iteration #179401 -- Total reward = -158.
# Iteration #179601 -- Total reward = -189.
# Iteration #179801 -- Total reward = -151.
# Iteration #180001 -- Total reward = -148.
# Iteration #180201 -- Total reward = -155.
# Iteration #180401 -- Total reward = -147.
# Iteration #180601 -- Total reward = -117.
# Iteration #180801 -- Total reward = -125.
# Iteration #181001 -- Total reward = -147.
# Iteration #181201 -- Total reward = -157.
# Iteration #181401 -- Total reward = -149.
# Iteration #181601 -- Total reward = -117.
# Iteration #181801 -- Total reward = -153.
# Iteration #182001 -- Total reward = -116.
# Iteration #182201 -- Total reward = -196.
# Iteration #182401 -- Total reward = -160.
# Iteration #182601 -- Total reward = -156.
# Iteration #182801 -- Total reward = -155.
# Iteration #183001 -- Total reward = -143.
# Iteration #183201 -- Total reward = -152.
# Iteration #183401 -- Total reward = -155.
# Iteration #183601 -- Total reward = -142.
# Iteration #183801 -- Total reward = -159.
# Iteration #184001 -- Total reward = -159.
# Iteration #184201 -- Total reward = -151.
# Iteration #184401 -- Total reward = -116.
# Iteration #184601 -- Total reward = -120.
# Iteration #184801 -- Total reward = -119.
# Iteration #185001 -- Total reward = -152.
# Iteration #185201 -- Total reward = -145.
# Iteration #185401 -- Total reward = -148.
# Iteration #185601 -- Total reward = -121.
# Iteration #185801 -- Total reward = -120.
# Iteration #186001 -- Total reward = -162.
# Iteration #186201 -- Total reward = -151.
# Iteration #186401 -- Total reward = -162.
# Iteration #186601 -- Total reward = -115.
# Iteration #186801 -- Total reward = -121.
# Iteration #187001 -- Total reward = -159.
# Iteration #187201 -- Total reward = -116.
# Iteration #187401 -- Total reward = -119.
# Iteration #187601 -- Total reward = -111.
# Iteration #187801 -- Total reward = -152.
# Iteration #188001 -- Total reward = -116.
# Iteration #188201 -- Total reward = -116.
# Iteration #188401 -- Total reward = -116.
# Iteration #188601 -- Total reward = -118.
# Iteration #188801 -- Total reward = -154.
# Iteration #189001 -- Total reward = -114.
# Iteration #189201 -- Total reward = -118.
# Iteration #189401 -- Total reward = -151.
# Iteration #189601 -- Total reward = -199.
# Iteration #189801 -- Total reward = -158.
# Iteration #190001 -- Total reward = -158.
# Iteration #190201 -- Total reward = -116.
# Iteration #190401 -- Total reward = -156.
# Iteration #190601 -- Total reward = -113.
# Iteration #190801 -- Total reward = -115.
# Iteration #191001 -- Total reward = -173.
# Iteration #191201 -- Total reward = -149.
# Iteration #191401 -- Total reward = -148.
# Iteration #191601 -- Total reward = -152.
# Iteration #191801 -- Total reward = -152.
# Iteration #192001 -- Total reward = -155.
# Iteration #192201 -- Total reward = -157.
# Iteration #192401 -- Total reward = -149.
# Iteration #192601 -- Total reward = -124.
# Iteration #192801 -- Total reward = -124.
# Iteration #193001 -- Total reward = -151.
# Iteration #193201 -- Total reward = -145.
# Iteration #193401 -- Total reward = -144.
# Iteration #193601 -- Total reward = -153.
# Iteration #193801 -- Total reward = -153.
# Iteration #194001 -- Total reward = -137.
# Iteration #194201 -- Total reward = -143.
# Iteration #194401 -- Total reward = -150.
# Iteration #194601 -- Total reward = -123.
# Iteration #194801 -- Total reward = -146.
# Iteration #195001 -- Total reward = -161.
# Iteration #195201 -- Total reward = -155.
# Iteration #195401 -- Total reward = -148.
# Iteration #195601 -- Total reward = -154.
# Iteration #195801 -- Total reward = -164.
# Iteration #196001 -- Total reward = -118.
# Iteration #196201 -- Total reward = -157.
# Iteration #196401 -- Total reward = -118.
# Iteration #196601 -- Total reward = -146.
# Iteration #196801 -- Total reward = -154.
# Iteration #197001 -- Total reward = -166.
# Iteration #197201 -- Total reward = -152.
# Iteration #197401 -- Total reward = -153.
# Iteration #197601 -- Total reward = -112.
# Iteration #197801 -- Total reward = -121.
# Iteration #198001 -- Total reward = -145.
# Iteration #198201 -- Total reward = -115.
# Iteration #198401 -- Total reward = -148.
# Iteration #198601 -- Total reward = -121.
# Iteration #198801 -- Total reward = -118.
# Iteration #199001 -- Total reward = -181.
# Iteration #199201 -- Total reward = -115.
# Iteration #199401 -- Total reward = -115.
# Iteration #199601 -- Total reward = -154.
# Iteration #199801 -- Total reward = -152.
# Iteration #200001 -- Total reward = -154.
# Iteration #200201 -- Total reward = -146.
# Iteration #200401 -- Total reward = -156.
# Iteration #200601 -- Total reward = -146.
# Iteration #200801 -- Total reward = -148.
# Iteration #201001 -- Total reward = -121.
# Iteration #201201 -- Total reward = -152.
# Iteration #201401 -- Total reward = -156.
# Iteration #201601 -- Total reward = -118.
# Iteration #201801 -- Total reward = -155.
# Iteration #202001 -- Total reward = -120.
# Iteration #202201 -- Total reward = -119.
# Iteration #202401 -- Total reward = -153.
# Iteration #202601 -- Total reward = -153.
# Iteration #202801 -- Total reward = -154.
# Iteration #203001 -- Total reward = -111.
# Iteration #203201 -- Total reward = -151.
# Iteration #203401 -- Total reward = -155.
# Iteration #203601 -- Total reward = -154.
# Iteration #203801 -- Total reward = -121.
# Iteration #204001 -- Total reward = -155.
# Iteration #204201 -- Total reward = -123.
# Iteration #204401 -- Total reward = -118.
# Iteration #204601 -- Total reward = -153.
# Iteration #204801 -- Total reward = -153.
# Iteration #205001 -- Total reward = -153.
# Iteration #205201 -- Total reward = -124.
# Iteration #205401 -- Total reward = -122.
# Iteration #205601 -- Total reward = -151.
# Iteration #205801 -- Total reward = -161.
# Iteration #206001 -- Total reward = -197.
# Iteration #206201 -- Total reward = -166.
# Iteration #206401 -- Total reward = -128.
# Iteration #206601 -- Total reward = -154.
# Iteration #206801 -- Total reward = -157.
# Iteration #207001 -- Total reward = -154.
# Iteration #207201 -- Total reward = -118.
# Iteration #207401 -- Total reward = -158.
# Iteration #207601 -- Total reward = -155.
# Iteration #207801 -- Total reward = -155.
# Iteration #208001 -- Total reward = -127.
# Iteration #208201 -- Total reward = -150.
# Iteration #208401 -- Total reward = -119.
# Iteration #208601 -- Total reward = -146.
# Iteration #208801 -- Total reward = -151.
# Iteration #209001 -- Total reward = -124.
# Iteration #209201 -- Total reward = -155.
# Iteration #209401 -- Total reward = -129.
# Iteration #209601 -- Total reward = -155.
# Iteration #209801 -- Total reward = -118.
# Iteration #210001 -- Total reward = -156.
# Iteration #210201 -- Total reward = -121.
# Iteration #210401 -- Total reward = -161.
# Iteration #210601 -- Total reward = -117.
# Iteration #210801 -- Total reward = -153.
# Iteration #211001 -- Total reward = -150.
# Iteration #211201 -- Total reward = -119.
# Iteration #211401 -- Total reward = -126.
# Iteration #211601 -- Total reward = -151.
# Iteration #211801 -- Total reward = -163.
# Iteration #212001 -- Total reward = -156.
# Iteration #212201 -- Total reward = -164.
# Iteration #212401 -- Total reward = -152.
# Iteration #212601 -- Total reward = -198.
# Iteration #212801 -- Total reward = -131.
# Iteration #213001 -- Total reward = -200.
# Iteration #213201 -- Total reward = -153.
# Iteration #213401 -- Total reward = -155.
# Iteration #213601 -- Total reward = -152.
# Iteration #213801 -- Total reward = -150.
# Iteration #214001 -- Total reward = -140.
# Iteration #214201 -- Total reward = -122.
# Iteration #214401 -- Total reward = -156.
# Iteration #214601 -- Total reward = -147.
# Iteration #214801 -- Total reward = -123.
# Iteration #215001 -- Total reward = -121.
# Iteration #215201 -- Total reward = -115.
# Iteration #215401 -- Total reward = -162.
# Iteration #215601 -- Total reward = -156.
# Iteration #215801 -- Total reward = -151.
# Iteration #216001 -- Total reward = -158.
# Iteration #216201 -- Total reward = -153.
# Iteration #216401 -- Total reward = -150.
# Iteration #216601 -- Total reward = -114.
# Iteration #216801 -- Total reward = -150.
# Iteration #217001 -- Total reward = -155.
# Iteration #217201 -- Total reward = -142.
# Iteration #217401 -- Total reward = -119.
# Iteration #217601 -- Total reward = -156.
# Iteration #217801 -- Total reward = -158.
# Iteration #218001 -- Total reward = -189.
# Iteration #218201 -- Total reward = -152.
# Iteration #218401 -- Total reward = -155.
# Iteration #218601 -- Total reward = -126.
# Iteration #218801 -- Total reward = -152.
# Iteration #219001 -- Total reward = -130.
# Iteration #219201 -- Total reward = -124.
# Iteration #219401 -- Total reward = -148.
# Iteration #219601 -- Total reward = -129.
# Iteration #219801 -- Total reward = -154.
# Iteration #220001 -- Total reward = -151.
# Iteration #220201 -- Total reward = -151.
# Iteration #220401 -- Total reward = -153.
# Iteration #220601 -- Total reward = -146.
# Iteration #220801 -- Total reward = -190.
# Iteration #221001 -- Total reward = -192.
# Iteration #221201 -- Total reward = -154.
# Iteration #221401 -- Total reward = -143.
# Iteration #221601 -- Total reward = -197.
# Iteration #221801 -- Total reward = -161.
# Iteration #222001 -- Total reward = -158.
# Iteration #222201 -- Total reward = -151.
# Iteration #222401 -- Total reward = -154.
# Iteration #222601 -- Total reward = -193.
# Iteration #222801 -- Total reward = -116.
# Iteration #223001 -- Total reward = -153.
# Iteration #223201 -- Total reward = -119.
# Iteration #223401 -- Total reward = -144.
# Iteration #223601 -- Total reward = -150.
# Iteration #223801 -- Total reward = -150.
# Iteration #224001 -- Total reward = -117.
# Iteration #224201 -- Total reward = -143.
# Iteration #224401 -- Total reward = -117.
# Iteration #224601 -- Total reward = -118.
# Iteration #224801 -- Total reward = -152.
# Iteration #225001 -- Total reward = -117.
# Iteration #225201 -- Total reward = -115.
# Iteration #225401 -- Total reward = -154.
# Iteration #225601 -- Total reward = -183.
# Iteration #225801 -- Total reward = -156.
# Iteration #226001 -- Total reward = -148.
# Iteration #226201 -- Total reward = -149.
# Iteration #226401 -- Total reward = -182.
# Iteration #226601 -- Total reward = -149.
# Iteration #226801 -- Total reward = -189.
# Iteration #227001 -- Total reward = -114.
# Iteration #227201 -- Total reward = -121.
# Iteration #227401 -- Total reward = -148.
# Iteration #227601 -- Total reward = -150.
# Iteration #227801 -- Total reward = -151.
# Iteration #228001 -- Total reward = -152.
# Iteration #228201 -- Total reward = -150.
# Iteration #228401 -- Total reward = -117.
# Iteration #228601 -- Total reward = -150.
# Iteration #228801 -- Total reward = -153.
# Iteration #229001 -- Total reward = -122.
# Iteration #229201 -- Total reward = -148.
# Iteration #229401 -- Total reward = -151.
# Iteration #229601 -- Total reward = -200.
# Iteration #229801 -- Total reward = -160.
# Iteration #230001 -- Total reward = -117.
# Iteration #230201 -- Total reward = -117.
# Iteration #230401 -- Total reward = -154.
# Iteration #230601 -- Total reward = -196.
# Iteration #230801 -- Total reward = -153.
# ...
# Iteration #924001 -- Total reward = -137.
# Iteration #924201 -- Total reward = -147.
# Iteration #924401 -- Total reward = -87.
# Iteration #924601 -- Total reward = -115.
# Iteration #924801 -- Total reward = -113.
# Iteration #925001 -- Total reward = -112.
# Iteration #925201 -- Total reward = -113.
# Iteration #925401 -- Total reward = -96.
# Iteration #925601 -- Total reward = -112.
# Iteration #925801 -- Total reward = -116.
# Iteration #926001 -- Total reward = -146.
# Iteration #926201 -- Total reward = -116.
# Iteration #926401 -- Total reward = -147.
# Iteration #926601 -- Total reward = -117.
# Iteration #926801 -- Total reward = -104.
# Iteration #927001 -- Total reward = -92.
# Iteration #927201 -- Total reward = -115.
# Iteration #927401 -- Total reward = -101.
# Iteration #927601 -- Total reward = -114.
# Iteration #927801 -- Total reward = -109.
# Iteration #928001 -- Total reward = -112.
# Iteration #928201 -- Total reward = -111.
# Iteration #928401 -- Total reward = -148.
# Iteration #928601 -- Total reward = -151.
# Iteration #928801 -- Total reward = -145.
# Iteration #929001 -- Total reward = -115.
# Iteration #929201 -- Total reward = -154.
# Iteration #929401 -- Total reward = -153.
# Iteration #929601 -- Total reward = -111.
# Iteration #929801 -- Total reward = -114.
# Iteration #930001 -- Total reward = -112.
# Iteration #930201 -- Total reward = -111.
# Iteration #930401 -- Total reward = -129.
# Iteration #930601 -- Total reward = -110.
# Iteration #930801 -- Total reward = -173.
# Iteration #931001 -- Total reward = -147.
# Iteration #931201 -- Total reward = -105.
# Iteration #931401 -- Total reward = -93.
# Iteration #931601 -- Total reward = -151.
# Iteration #931801 -- Total reward = -108.
# Iteration #932001 -- Total reward = -159.
# Iteration #932201 -- Total reward = -149.
# Iteration #932401 -- Total reward = -113.
# Iteration #932601 -- Total reward = -149.
# Iteration #932801 -- Total reward = -173.
# Iteration #933001 -- Total reward = -124.
# Iteration #933201 -- Total reward = -144.
# Iteration #933401 -- Total reward = -94.
# Iteration #933601 -- Total reward = -146.
# Iteration #933801 -- Total reward = -109.
# Iteration #934001 -- Total reward = -156.
# Iteration #934201 -- Total reward = -143.
# Iteration #934401 -- Total reward = -145.
# Iteration #934601 -- Total reward = -159.
# Iteration #934801 -- Total reward = -90.
# Iteration #935001 -- Total reward = -121.
# Iteration #935201 -- Total reward = -95.
# Iteration #935401 -- Total reward = -112.
# Iteration #935601 -- Total reward = -113.
# Iteration #935801 -- Total reward = -90.
# Iteration #936001 -- Total reward = -111.
# Iteration #936201 -- Total reward = -158.
# Iteration #936401 -- Total reward = -114.
# Iteration #936601 -- Total reward = -148.
# Iteration #936801 -- Total reward = -110.
# Iteration #937001 -- Total reward = -119.
# Iteration #937201 -- Total reward = -104.
# Iteration #937401 -- Total reward = -145.
# Iteration #937601 -- Total reward = -145.
# Iteration #937801 -- Total reward = -117.
# Iteration #938001 -- Total reward = -92.
# Iteration #938201 -- Total reward = -112.
# Iteration #938401 -- Total reward = -114.
# Iteration #938601 -- Total reward = -153.
# Iteration #938801 -- Total reward = -141.
# Iteration #939001 -- Total reward = -87.
# Iteration #939201 -- Total reward = -92.
# Iteration #939401 -- Total reward = -113.
# Iteration #939601 -- Total reward = -150.
# Iteration #939801 -- Total reward = -110.
# Iteration #940001 -- Total reward = -150.
# Iteration #940201 -- Total reward = -147.
# Iteration #940401 -- Total reward = -170.
# Iteration #940601 -- Total reward = -144.
# Iteration #940801 -- Total reward = -110.
# Iteration #941001 -- Total reward = -123.
# Iteration #941201 -- Total reward = -113.
# Iteration #941401 -- Total reward = -105.
# Iteration #941601 -- Total reward = -142.
# Iteration #941801 -- Total reward = -109.
# Iteration #942001 -- Total reward = -113.
# Iteration #942201 -- Total reward = -118.
# Iteration #942401 -- Total reward = -148.
# Iteration #942601 -- Total reward = -166.
# Iteration #942801 -- Total reward = -112.
# Iteration #943001 -- Total reward = -163.
# Iteration #943201 -- Total reward = -156.
# Iteration #943401 -- Total reward = -147.
# Iteration #943601 -- Total reward = -110.
# Iteration #943801 -- Total reward = -151.
# Iteration #944001 -- Total reward = -181.
# Iteration #944201 -- Total reward = -92.
# Iteration #944401 -- Total reward = -114.
# Iteration #944601 -- Total reward = -167.
# Iteration #944801 -- Total reward = -95.
# Iteration #945001 -- Total reward = -92.
# Iteration #945201 -- Total reward = -108.
# Iteration #945401 -- Total reward = -117.
# Iteration #945601 -- Total reward = -158.
# Iteration #945801 -- Total reward = -89.
# Iteration #946001 -- Total reward = -110.
# Iteration #946201 -- Total reward = -150.
# Iteration #946401 -- Total reward = -89.
# Iteration #946601 -- Total reward = -109.
# Iteration #946801 -- Total reward = -148.
# Iteration #947001 -- Total reward = -155.
# Iteration #947201 -- Total reward = -147.
# Iteration #947401 -- Total reward = -112.
# Iteration #947601 -- Total reward = -148.
# Iteration #947801 -- Total reward = -108.
# Iteration #948001 -- Total reward = -100.
# Iteration #948201 -- Total reward = -110.
# Iteration #948401 -- Total reward = -155.
# Iteration #948601 -- Total reward = -109.
# Iteration #948801 -- Total reward = -149.
# Iteration #949001 -- Total reward = -111.
# Iteration #949201 -- Total reward = -122.
# Iteration #949401 -- Total reward = -107.
# Iteration #949601 -- Total reward = -145.
# Iteration #949801 -- Total reward = -148.
# Iteration #950001 -- Total reward = -149.
# Iteration #950201 -- Total reward = -114.
# Iteration #950401 -- Total reward = -102.
# Iteration #950601 -- Total reward = -113.
# Iteration #950801 -- Total reward = -117.
# Iteration #951001 -- Total reward = -155.
# Iteration #951201 -- Total reward = -189.
# Iteration #951401 -- Total reward = -113.
# Iteration #951601 -- Total reward = -107.
# Iteration #951801 -- Total reward = -154.
# Iteration #952001 -- Total reward = -154.
# Iteration #952201 -- Total reward = -107.
# Iteration #952401 -- Total reward = -106.
# Iteration #952601 -- Total reward = -145.
# Iteration #952801 -- Total reward = -127.
# Iteration #953001 -- Total reward = -106.
# Iteration #953201 -- Total reward = -146.
# Iteration #953401 -- Total reward = -160.
# Iteration #953601 -- Total reward = -168.
# Iteration #953801 -- Total reward = -142.
# Iteration #954001 -- Total reward = -113.
# Iteration #954201 -- Total reward = -148.
# Iteration #954401 -- Total reward = -92.
# Iteration #954601 -- Total reward = -113.
# Iteration #954801 -- Total reward = -141.
# Iteration #955001 -- Total reward = -111.
# Iteration #955201 -- Total reward = -146.
# Iteration #955401 -- Total reward = -154.
# Iteration #955601 -- Total reward = -109.
# Iteration #955801 -- Total reward = -108.
# Iteration #956001 -- Total reward = -144.
# Iteration #956201 -- Total reward = -112.
# Iteration #956401 -- Total reward = -148.
# Iteration #956601 -- Total reward = -107.
# Iteration #956801 -- Total reward = -116.
# Iteration #957001 -- Total reward = -148.
# Iteration #957201 -- Total reward = -105.
# Iteration #957401 -- Total reward = -110.
# Iteration #957601 -- Total reward = -110.
# Iteration #957801 -- Total reward = -176.
# Iteration #958001 -- Total reward = -109.
# Iteration #958201 -- Total reward = -110.
# Iteration #958401 -- Total reward = -111.
# Iteration #958601 -- Total reward = -167.
# Iteration #958801 -- Total reward = -108.
# Iteration #959001 -- Total reward = -153.
# Iteration #959201 -- Total reward = -153.
# Iteration #959401 -- Total reward = -144.
# Iteration #959601 -- Total reward = -141.
# Iteration #959801 -- Total reward = -158.
# Iteration #960001 -- Total reward = -116.
# Iteration #960201 -- Total reward = -110.
# Iteration #960401 -- Total reward = -142.
# Iteration #960601 -- Total reward = -109.
# Iteration #960801 -- Total reward = -110.
# Iteration #961001 -- Total reward = -156.
# Iteration #961201 -- Total reward = -111.
# Iteration #961401 -- Total reward = -147.
# Iteration #961601 -- Total reward = -109.
# Iteration #961801 -- Total reward = -112.
# Iteration #962001 -- Total reward = -116.
# Iteration #962201 -- Total reward = -143.
# Iteration #962401 -- Total reward = -148.
# Iteration #962601 -- Total reward = -156.
# Iteration #962801 -- Total reward = -143.
# Iteration #963001 -- Total reward = -108.
# Iteration #963201 -- Total reward = -111.
# Iteration #963401 -- Total reward = -110.
# Iteration #963601 -- Total reward = -151.
# Iteration #963801 -- Total reward = -157.
# Iteration #964001 -- Total reward = -148.
# Iteration #964201 -- Total reward = -108.
# Iteration #964401 -- Total reward = -156.
# Iteration #964601 -- Total reward = -110.
# Iteration #964801 -- Total reward = -150.
# Iteration #965001 -- Total reward = -146.
# Iteration #965201 -- Total reward = -154.
# Iteration #965401 -- Total reward = -109.
# Iteration #965601 -- Total reward = -109.
# Iteration #965801 -- Total reward = -144.
# Iteration #966001 -- Total reward = -111.
# Iteration #966201 -- Total reward = -148.
# Iteration #966401 -- Total reward = -109.
# Iteration #966601 -- Total reward = -109.
# Iteration #966801 -- Total reward = -152.
# Iteration #967001 -- Total reward = -114.
# Iteration #967201 -- Total reward = -145.
# Iteration #967401 -- Total reward = -147.
# Iteration #967601 -- Total reward = -114.
# Iteration #967801 -- Total reward = -110.
# Iteration #968001 -- Total reward = -150.
# Iteration #968201 -- Total reward = -111.
# Iteration #968401 -- Total reward = -112.
# Iteration #968601 -- Total reward = -141.
# Iteration #968801 -- Total reward = -147.
# Iteration #969001 -- Total reward = -110.
# Iteration #969201 -- Total reward = -144.
# Iteration #969401 -- Total reward = -145.
# Iteration #969601 -- Total reward = -144.
# Iteration #969801 -- Total reward = -107.
# Iteration #970001 -- Total reward = -149.
# Iteration #970201 -- Total reward = -147.
# Iteration #970401 -- Total reward = -143.
# Iteration #970601 -- Total reward = -141.
# Iteration #970801 -- Total reward = -142.
# Iteration #971001 -- Total reward = -144.
# Iteration #971201 -- Total reward = -115.
# Iteration #971401 -- Total reward = -143.
# Iteration #971601 -- Total reward = -115.
# Iteration #971801 -- Total reward = -107.
# Iteration #972001 -- Total reward = -108.
# Iteration #972201 -- Total reward = -148.
# Iteration #972401 -- Total reward = -113.
# Iteration #972601 -- Total reward = -113.
# Iteration #972801 -- Total reward = -106.
# Iteration #973001 -- Total reward = -114.
# Iteration #973201 -- Total reward = -144.
# Iteration #973401 -- Total reward = -138.
# Iteration #973601 -- Total reward = -113.
# Iteration #973801 -- Total reward = -140.
# Iteration #974001 -- Total reward = -140.
# Iteration #974201 -- Total reward = -109.
# Iteration #974401 -- Total reward = -142.
# Iteration #974601 -- Total reward = -138.
# Iteration #974801 -- Total reward = -147.
# Iteration #975001 -- Total reward = -144.
# Iteration #975201 -- Total reward = -115.
# Iteration #975401 -- Total reward = -156.
# Iteration #975601 -- Total reward = -114.
# Iteration #975801 -- Total reward = -144.
# Iteration #976001 -- Total reward = -144.
# Iteration #976201 -- Total reward = -141.
# Iteration #976401 -- Total reward = -108.
# Iteration #976601 -- Total reward = -139.
# Iteration #976801 -- Total reward = -142.
# Iteration #977001 -- Total reward = -114.
# Iteration #977201 -- Total reward = -109.
# Iteration #977401 -- Total reward = -111.
# Iteration #977601 -- Total reward = -146.
# Iteration #977801 -- Total reward = -145.
# Iteration #978001 -- Total reward = -118.
# Iteration #978201 -- Total reward = -110.
# Iteration #978401 -- Total reward = -115.
# Iteration #978601 -- Total reward = -123.
# Iteration #978801 -- Total reward = -108.
# Iteration #979001 -- Total reward = -152.
# Iteration #979201 -- Total reward = -109.
# Iteration #979401 -- Total reward = -107.
# Iteration #979601 -- Total reward = -108.
# Iteration #979801 -- Total reward = -120.
# Iteration #980001 -- Total reward = -147.
# Iteration #980201 -- Total reward = -153.
# Iteration #980401 -- Total reward = -165.
# Iteration #980601 -- Total reward = -117.
# Iteration #980801 -- Total reward = -156.
# Iteration #981001 -- Total reward = -123.
# Iteration #981201 -- Total reward = -149.
# Iteration #981401 -- Total reward = -116.
# Iteration #981601 -- Total reward = -154.
# Iteration #981801 -- Total reward = -98.
# Iteration #982001 -- Total reward = -115.
# Iteration #982201 -- Total reward = -111.
# Iteration #982401 -- Total reward = -113.
# Iteration #982601 -- Total reward = -111.
# Iteration #982801 -- Total reward = -109.
# Iteration #983001 -- Total reward = -144.
# Iteration #983201 -- Total reward = -177.
# Iteration #983401 -- Total reward = -145.
# Iteration #983601 -- Total reward = -123.
# Iteration #983801 -- Total reward = -111.
# Iteration #984001 -- Total reward = -109.
# Iteration #984201 -- Total reward = -112.
# Iteration #984401 -- Total reward = -118.
# Iteration #984601 -- Total reward = -145.
# Iteration #984801 -- Total reward = -172.
# Iteration #985001 -- Total reward = -142.
# Iteration #985201 -- Total reward = -141.
# Iteration #985401 -- Total reward = -160.
# Iteration #985601 -- Total reward = -149.
# Iteration #985801 -- Total reward = -146.
# Iteration #986001 -- Total reward = -158.
# Iteration #986201 -- Total reward = -144.
# Iteration #986401 -- Total reward = -109.
# Iteration #986601 -- Total reward = -126.
# Iteration #986801 -- Total reward = -109.
# Iteration #987001 -- Total reward = -111.
# Iteration #987201 -- Total reward = -148.
# Iteration #987401 -- Total reward = -142.
# Iteration #987601 -- Total reward = -110.
# Iteration #987801 -- Total reward = -146.
# Iteration #988001 -- Total reward = -110.
# Iteration #988201 -- Total reward = -152.
# Iteration #988401 -- Total reward = -122.
# Iteration #988601 -- Total reward = -109.
# Iteration #988801 -- Total reward = -89.
# Iteration #989001 -- Total reward = -117.
# Iteration #989201 -- Total reward = -145.
# Iteration #989401 -- Total reward = -119.
# Iteration #989601 -- Total reward = -115.
# Iteration #989801 -- Total reward = -113.
# Iteration #990001 -- Total reward = -100.
# Iteration #990201 -- Total reward = -138.
# Iteration #990401 -- Total reward = -100.
# Iteration #990601 -- Total reward = -113.
# Iteration #990801 -- Total reward = -117.
# Iteration #991001 -- Total reward = -112.
# Iteration #991201 -- Total reward = -148.
# Iteration #991401 -- Total reward = -113.
# Iteration #991601 -- Total reward = -130.
# Iteration #991801 -- Total reward = -92.
# Iteration #992001 -- Total reward = -90.
# Iteration #992201 -- Total reward = -137.
# Iteration #992401 -- Total reward = -111.
# Iteration #992601 -- Total reward = -162.
# Iteration #992801 -- Total reward = -194.
# Iteration #993001 -- Total reward = -169.
# Iteration #993201 -- Total reward = -156.
# Iteration #993401 -- Total reward = -146.
# Iteration #993601 -- Total reward = -93.
# Iteration #993801 -- Total reward = -167.
# Iteration #994001 -- Total reward = -145.
# Iteration #994201 -- Total reward = -98.
# Iteration #994401 -- Total reward = -150.
# Iteration #994601 -- Total reward = -140.
# Iteration #994801 -- Total reward = -118.
# Iteration #995001 -- Total reward = -144.
# Iteration #995201 -- Total reward = -180.
# Iteration #995401 -- Total reward = -147.
# Iteration #995601 -- Total reward = -126.
# Iteration #995801 -- Total reward = -144.
# Iteration #996001 -- Total reward = -153.
# Iteration #996201 -- Total reward = -155.
# Iteration #996401 -- Total reward = -149.
# Iteration #996601 -- Total reward = -124.
# Iteration #996801 -- Total reward = -137.
# Iteration #997001 -- Total reward = -151.
# Iteration #997201 -- Total reward = -117.
# Iteration #997401 -- Total reward = -119.
# Iteration #997601 -- Total reward = -127.
# Iteration #997801 -- Total reward = -154.
# Iteration #998001 -- Total reward = -159.
# Iteration #998201 -- Total reward = -153.
# Iteration #998401 -- Total reward = -146.
# Iteration #998601 -- Total reward = -118.
# Iteration #998801 -- Total reward = -119.
# Iteration #999001 -- Total reward = -150.
# Iteration #999201 -- Total reward = -171.
# Iteration #999401 -- Total reward = -160.
# Iteration #999601 -- Total reward = -124.
# Iteration #999801 -- Total reward = -145.
# Average score of solution =  -116.56

# %%
np.mean([run_episode(env, solution_policy, False) for _ in range(100)])
# Out:
# -112.7

# %% [markdown]
# ## test

# %%
import gym
import numpy as np

q_table = np.load('mountiancar-v0_Qtable_Qlearning.npy')

name = "MountainCar-v0"
env = gym.make(name)

n_states = 40
def obs_to_state(env, obs):
    """
    Map an observation to state
    discrete the continuous observation space
    """
    env_low = env.observation_space.low
    env_high = env.observation_space.high
    env_dx = (env_high - env_low) / n_states
    a = int((obs[0] - env_low[0])/env_dx[0])
    b = int((obs[1] - env_low[1])/env_dx[1])
    return a, b

def run_episode(env, policy=None, render=False):
    obs = env.reset()
    total_reward = 0
    steps = 0
    for _ in range(t_max):
        if render:
            env.render()
        if policy is None:
            action = env.action_space.sample()
        else:
            a, b = obs_to_state(env, obs)
            action = policy[a][b]
        obs, reward, done, _ = env.step(action)
        total_reward += gamma**steps * reward
        steps += 1
        
        if done:
            break
    return total_reward

solution_policy = np.argmax(q_table, axis=2)

print(np.mean([run_episode(env, solution_policy, False) for _ in range(100)]))

run_episode(env, solution_policy, True)
